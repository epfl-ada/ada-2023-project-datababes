# %%
# imports

import pandas as pd 
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import plotly.express as px
import plotly.graph_objects as go

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import spacy
from collections import Counter

# %%
import json

# %%
# Turn off warnings
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# ## Preprocessing

# %%
# loading the two datasets 

ratings_ba_df = pd.read_csv('data/BeerAdvocate/ratings_BA.csv')
ratings_rb_df = pd.read_csv('data/RateBeer/ratings_RB.csv')


# loading the users dataset 

users_ba_df = pd.read_csv('data/BeerAdvocate/users.csv')
users_rb_df = pd.read_csv('data/RateBeer/users.csv')

# loading the beers dataset

beers_ba_df = pd.read_csv('data/BeerAdvocate/beers.csv')
beers_rb_df = pd.read_csv('data/RateBeer/beers.csv')

# %%
# Convert the date column to datetime format for BeerAdvocate
ratings_ba_df['date'] = pd.to_datetime(ratings_ba_df['date'], unit='s')
ratings_ba_df['year'] = ratings_ba_df['date'].dt.year
ratings_ba_df['month'] = ratings_ba_df['date'].dt.month

# Convert the date column to datetime format for RateBeer
ratings_rb_df['date'] = pd.to_datetime(ratings_rb_df['date'], unit='s')
ratings_rb_df['year'] = ratings_rb_df['date'].dt.year
ratings_rb_df['month'] = ratings_rb_df['date'].dt.month

# %% [markdown]
# ## Filter on location

# %%
users_rb_df['location'] = users_rb_df['location'].str.split(',').str[0]
users_ba_df['location'] = users_ba_df['location'].str.split(',').str[0]

US_country = 'United States'

# keep only the rows where the user country is United States
users_ba_df = users_ba_df[users_ba_df.location == US_country]
users_rb_df = users_rb_df[users_rb_df.location == US_country]

# merge the ratings and users data frames to get the location of the user for each rating
ratings_users_ba_df = pd.merge(ratings_ba_df, users_ba_df[['user_id', 'location']], on='user_id', how='inner')
ratings_users_rb_df = pd.merge(ratings_rb_df, users_rb_df[['user_id', 'location']], on='user_id', how='inner')

# filter the ratings dataframes to only keep the popular ratings of the users from the US
ratings_ba_df = ratings_users_ba_df[ratings_users_ba_df.location == US_country]
ratings_ba_df.drop('location', axis=1, inplace=True)
ratings_rb_df = ratings_users_rb_df[ratings_users_rb_df.location == US_country]
ratings_rb_df.drop('location', axis=1, inplace=True)

# %% [markdown]
# ## Separate the good ratings and bad ratings

# %%
mean_ba = ratings_ba_df.rating.mean()
mean_rb = ratings_rb_df.rating.mean()

print("Mean rating in BeerAdvocate:", mean_ba)
print("Mean rating in RateBeer:", mean_rb)
# Out:
# Mean rating in BeerAdvocate: 3.846906563579535
# Mean rating in RateBeer: 3.3793541115704993

# %%
ratings_ba_df_untouched = ratings_ba_df.copy()
ratings_rb_df_untouched = ratings_rb_df.copy()

# Filter the ratings dataframes to only keep the popular ratings
good_ratings_ba_df = ratings_ba_df[ratings_ba_df['rating'] > mean_ba]
good_ratings_rb_df = ratings_rb_df[ratings_rb_df['rating'] > mean_rb]

bad_ratings_ba_df = ratings_ba_df[ratings_ba_df['rating'] <= mean_ba]
bad_ratings_rb_df = ratings_rb_df[ratings_rb_df['rating'] <= mean_rb]

# %%
# merge the two ratings data frames
good_ratings_combined_df = pd.concat([good_ratings_ba_df, good_ratings_rb_df], ignore_index=True)
bad_ratings_combined_df = pd.concat([bad_ratings_ba_df, bad_ratings_rb_df], ignore_index=True)

# %% [markdown]
# ## Textual analysis

# %%
nlp = spacy.load('en_core_web_sm')

# %%
# drop rows where text is missing
good_ratings_combined_df.dropna(subset=['text'], inplace=True)
bad_ratings_combined_df.dropna(subset=['text'], inplace=True)

# %%
# Keywords for each category
aroma_keywords = ['aroma', 'smell', 'fragrance', 'scent', 'finish']
taste_keywords = ['taste', 'flavor', 'palate']
palate_keywords = ['palate', 'mouthfeel', 'body', 'texture', 'feel']
appearance_keywords = ['appearance', 'color', 'look', 'pour', 'head', 'foam', 'lacing']
carbonation_keywords = ['carbonation', 'bubbles', 'fizz', 'carbonated']

# %% [markdown]
# ## Keywords extraction of the good reviews

# %%
def extract_keywords(text, keywords):
    # Process the text with spaCy
    doc = nlp(text.lower())

    result = []
    for token in doc:
        if token.text.lower() in keywords:
            # Collect nearby adjectives and nouns
            nearby_words = []
            for nearby_token in doc[token.i - 3:token.i + 5]:
                if nearby_token.pos_ in ['ADJ', 'NOUN'] and not nearby_token.is_stop and len(nearby_token) > 2:
                    nearby_words.append(nearby_token.lemma_)
            result.extend(nearby_words)
            
    # remove the duplicates and the words that are in the keywords list
    result = list(set(result) - set(keywords))

    return result

# %%
# group by beer_id and count the number of reviews for each beer
beer_reviews_count = good_ratings_combined_df.groupby('beer_id').count()['text'].reset_index()

# %%
# print the average number of reviews
print("Average number of reviews per beer:", beer_reviews_count.text.mean())
# Out:
# Average number of reviews per beer: 13.480106777795909

# %%
beer_reviews_count.describe()
# Out:
#              beer_id           text
# count  239001.000000  239001.000000
# mean   221272.727223      13.480107
# std    150582.412973      71.936676
# min         1.000000       1.000000
# 25%     89204.000000       1.000000
# 50%    201842.000000       2.000000
# 75%    336505.000000       6.000000
# max    536465.000000    4943.000000

# %%
# plot histogram of the number of reviews with log scale
plt.figure(figsize=(12, 6))
plt.hist(beer_reviews_count.text, bins=100)
plt.xlabel('Number of reviews')
plt.ylabel('Number of beers')
plt.title('Histogram of the number of reviews per beer (log scale)')
plt.yscale('log')
plt.show()

# %% [markdown]
# The average of ratings received for a beer is 13.48, rounded to 14, with a standard deviation of 71.93.
# Since we have a lot of beers, and some of them receive a large amount of reviews, we decide to threshold the reviews.
# We assume that, in general, beers receive kind of the same review when it is a good review, and same goes for bad reviews. That's why we split the reviews into two parts, so that we can construct dictionnaries for good and for bad reviews.
#
# Let's keep a maximum review of 100 for each beer.

# %%
# for each beer_id, keep a maximum sample of mean reviews
mean = 14
beer_reviews_sample = good_ratings_combined_df.groupby('beer_id').apply(lambda x: x.sample(min(len(x), mean))).reset_index(drop=True)

# %%
len(beer_reviews_sample)
# Out:
# 1028394

# %%
good_aroma_list = []
good_taste_list = []
good_palate_list = []
good_appearance_list = []
good_carbonation_list = []

sample_reviews = beer_reviews_sample['text'].sample(100000)

for i, text in enumerate(sample_reviews.values.tolist()):
    # for each keyword list, extract the keywords from the text
    good_aroma_list.extend(extract_keywords(text, aroma_keywords))
    good_taste_list.extend(extract_keywords(text, taste_keywords))
    good_palate_list.extend(extract_keywords(text, palate_keywords))
    good_appearance_list.extend(extract_keywords(text, appearance_keywords))
    good_carbonation_list.extend(extract_keywords(text, carbonation_keywords))
    
    aroma_set = Counter(good_aroma_list)
    taste_set = Counter(good_taste_list)
    palate_set = Counter(good_palate_list)
    appearance_set = Counter(good_appearance_list)
    carbonation_set = Counter(good_carbonation_list)
    
    if i % 1000 == 0:
        # save it into json files
        with open('data/aroma_keywords_2.json', 'w') as f:
            json.dump(aroma_set, f)
        
        with open('data/taste_keywords_2.json', 'w') as f:
            json.dump(taste_set, f)
        
        with open('data/palate_keywords_2.json', 'w') as f:
            json.dump(palate_set, f)
        
        with open('data/appearance_keywords_2.json', 'w') as f:
            json.dump(appearance_set, f)
        
        with open('data/carbonation_keywords_2.json', 'w') as f:
            json.dump(carbonation_set, f)
            
        print("File saved at iteration", i)

# %% [markdown]
# ## Cleaning the list of keywords

# %%
# open the json files and load them into a dictionary
with open('data/aroma_keywords_2.json') as f:
    aroma_dict = json.load(f)

with open('data/taste_keywords_2.json') as f:
    taste_dict = json.load(f)
    
with open('data/palate_keywords_2.json') as f:
    palate_dict = json.load(f)

with open('data/appearance_keywords_2.json') as f:
    appearance_dict = json.load(f)
    
with open('data/carbonation_keywords_2.json') as f:
    carbonation_dict = json.load(f)

# %%
# concatenate all the keywords aroma_keywords, taste_keywords, palate_keywords, appearance_keywords, carbonation_keywords
all_keywords = aroma_keywords + taste_keywords + palate_keywords + appearance_keywords + carbonation_keywords

# create a function to filter the keys from the dictionary
def filter_keywords(keywords):
    filtered_keywords = []
    
    for keyword in keywords:
        
        # remove the keyowrds that have special characters, numbers and punctuation
        if not re.match('^[a-zA-Z]+$', keyword):
            continue
        
        # remove the keywords that are less than 3 characters
        if len(keyword) < 3:
            continue
        
        # remove keywords that have the word 'beer' in them
        if keyword == 'beer':
            continue
        
        # remove keywords such as not, like, well, etc.
        if keyword in ['not', 'one', 'like', 'well', 'good', 'great', 'nice', 'little', 'much', 'really', 'bit', 'very', 'with', 'more', 'and', 'but', 'too', 'also', 'just']:
            continue
        
        # remove words such as hop, hoppy, malt, malty, etc.
        if keyword in ['hop', 'hops', 'hoppy', 'malt', 'malts', 'malty', 'maltiness', 'maltinesses']:
            continue
        
        # if the keyword is not in the all_keywords list, add it to the filtered_keywords list
        if keyword not in all_keywords:
            filtered_keywords.append(keyword)
    
    return filtered_keywords

# %%
# filter the keywords
aroma_words = filter_keywords(aroma_dict.keys())
taste_words = filter_keywords(taste_dict.keys())
palate_words = filter_keywords(palate_dict.keys())
appearance_words = filter_keywords(appearance_dict.keys())
carbonation_words = filter_keywords(carbonation_dict.keys())

# reconstruct the dictionaries with the filtered keywords
aroma_dict = {key: aroma_dict[key] for key in aroma_words}
taste_dict = {key: taste_dict[key] for key in taste_words}
palate_dict = {key: palate_dict[key] for key in palate_words}
appearance_dict = {key: appearance_dict[key] for key in appearance_words}
carbonation_dict = {key: carbonation_dict[key] for key in carbonation_words}

# %%
# sort the dictionaries by value
aroma_dict = dict(sorted(aroma_dict.items(), key=lambda item: item[1], reverse=True))
taste_dict = dict(sorted(taste_dict.items(), key=lambda item: item[1], reverse=True))
palate_dict = dict(sorted(palate_dict.items(), key=lambda item: item[1], reverse=True))
appearance_dict = dict(sorted(appearance_dict.items(), key=lambda item: item[1], reverse=True))
carbonation_dict = dict(sorted(carbonation_dict.items(), key=lambda item: item[1], reverse=True))

# %%
# print the size of each dictionary
print("Number of aroma keywords:", len(aroma_dict))
print("Number of taste keywords:", len(taste_dict))
print("Number of palate keywords:", len(palate_dict))
print("Number of appearance keywords:", len(appearance_dict))
print("Number of carbonation keywords:", len(carbonation_dict))
# Out:
# Number of aroma keywords: 5263
# Number of taste keywords: 5513
# Number of palate keywords: 4444
# Number of appearance keywords: 5760
# Number of carbonation keywords: 2740

# %%
appearance_dict
# Out:
# {'white': 30014,
#  'brown': 7331,
#  'light': 7032,
#  'small': 6816,
#  'thin': 5672,
#  'dark': 5597,
#  'golden': 5360,
#  'finger': 4840,
#  'nose': 4764,
#  'retention': 4653,
#  'medium': 4194,
#  'hazy': 4085,
#  'clear': 3961,
#  'amber': 3770,
#  'black': 3743,
#  'creamy': 3614,
#  'thick': 3372,
#  'beige': 3313,
#  'orange': 3310,
#  'yellow': 3229,
#  'glass': 2812,
#  'tan': 2801,
#  'foamy': 2581,
#  'copper': 2451,
#  'sweet': 2319,
#  'big': 2239,
#  'gold': 2146,
#  'decent': 2067,
#  'deep': 2061,
#  'cloudy': 2037,
#  'lace': 1908,
#  'moderate': 1585,
#  'fluffy': 1559,
#  'lot': 1440,
#  'sized': 1387,
#  'large': 1367,
#  'inch': 1337,
#  'red': 1329,
#  'minimal': 1243,
#  'sticky': 1232,
#  'ring': 1199,
#  'bright': 1165,
#  'colored': 1144,
#  'spotty': 1084,
#  'citrus': 1083,
#  'straw': 1059,
#  'chocolate': 1053,
#  'dense': 1016,
#  'reddish': 1005,
#  'pale': 994,
#  'khaki': 968,
#  'fruity': 917,
#  'slight': 893,
#  'rich': 879,
#  'cream': 874,
#  'soapy': 870,
#  'huge': 861,
#  'excellent': 847,
#  'coffee': 799,
#  'fizzy': 769,
#  'frothy': 743,
#  'solid': 738,
#  'roasted': 705,
#  'bubbly': 703,
#  'average': 697,
#  'floral': 695,
#  'mild': 694,
#  'strong': 688,
#  'short': 685,
#  'bubble': 675,
#  'heavy': 597,
#  'caramel': 595,
#  'soft': 592,
#  'pink': 581,
#  'mocha': 580,
#  'beautiful': 575,
#  'opaque': 567,
#  'murky': 541,
#  'ruby': 523,
#  'note': 512,
#  'fruit': 507,
#  'rocky': 498,
#  'fine': 494,
#  'cling': 467,
#  'tart': 462,
#  'half': 445,
#  'cap': 438,
#  'tropical': 428,
#  'tall': 422,
#  'bottle': 411,
#  'grapefruit': 389,
#  'layer': 373,
#  'roasty': 368,
#  'fresh': 367,
#  'mahogany': 366,
#  'modest': 362,
#  'sour': 358,
#  'earthy': 357,
#  'edge': 351,
#  'honey': 345,
#  'tight': 344,
#  'brownish': 339,
#  'pine': 329,
#  'dissipate': 318,
#  'ton': 316,
#  'fair': 307,
#  'hue': 300,
#  'spicy': 298,
#  'lemon': 294,
#  'tiny': 292,
#  'yeast': 287,
#  'brewery': 282,
#  'lasting': 280,
#  'wheat': 280,
#  'haze': 278,
#  'pitch': 273,
#  'plenty': 271,
#  'smooth': 267,
#  'sheet': 256,
#  'vanilla': 254,
#  'bitter': 253,
#  'tap': 251,
#  'massive': 245,
#  'clarity': 244,
#  'wispy': 242,
#  'cherry': 240,
#  'highlight': 236,
#  'eggshell': 236,
#  'dry': 235,
#  'film': 233,
#  'clean': 233,
#  'fade': 232,
#  'low': 231,
#  'funky': 230,
#  'pint': 227,
#  'surface': 225,
#  'long': 220,
#  'cocoa': 218,
#  'roast': 217,
#  'side': 216,
#  'bourbon': 216,
#  'ivory': 215,
#  'purple': 213,
#  'lacy': 204,
#  'bone': 204,
#  'high': 203,
#  'hint': 203,
#  'brew': 200,
#  'form': 200,
#  'pinkish': 197,
#  'lovely': 196,
#  'quick': 196,
#  'spot': 195,
#  'semi': 193,
#  'way': 193,
#  'crisp': 189,
#  'spice': 187,
#  'pillowy': 186,
#  'bread': 185,
#  'initial': 182,
#  'faint': 181,
#  'citrusy': 180,
#  'persistent': 178,
#  'bready': 178,
#  'peach': 178,
#  'toffee': 176,
#  'worth': 173,
#  'smallish': 172,
#  'belgian': 169,
#  'grain': 169,
#  'pure': 168,
#  'dirty': 163,
#  'loose': 162,
#  'real': 162,
#  'yeasty': 161,
#  'tulip': 161,
#  'jet': 160,
#  'cola': 158,
#  'snifter': 158,
#  'chestnut': 157,
#  'stick': 153,
#  'draft': 152,
#  'yellowish': 152,
#  'herbal': 151,
#  'size': 149,
#  'aggressive': 148,
#  'pineapple': 146,
#  'string': 145,
#  'perfect': 143,
#  'milk': 141,
#  'grassy': 141,
#  'patchy': 141,
#  'super': 141,
#  'juicy': 138,
#  'leg': 138,
#  'wonderful': 138,
#  'ale': 137,
#  'coppery': 137,
#  'attractive': 137,
#  'fantastic': 136,
#  'typical': 135,
#  'collar': 135,
#  'pleasant': 132,
#  'time': 131,
#  'amazing': 131,
#  'orangish': 131,
#  'apple': 130,
#  'patch': 127,
#  'wisp': 127,
#  'awesome': 125,
#  'impressive': 122,
#  'subtle': 122,
#  'amount': 121,
#  'bronze': 121,
#  'slow': 121,
#  'whitish': 121,
#  'gorgeous': 118,
#  'tannish': 118,
#  'ample': 118,
#  'juice': 117,
#  'generous': 116,
#  'complex': 114,
#  'ecru': 112,
#  'interesting': 111,
#  'touch': 111,
#  'muddy': 111,
#  'stout': 109,
#  'style': 109,
#  'raspberry': 107,
#  'froth': 106,
#  'translucent': 106,
#  'near': 105,
#  'weak': 105,
#  'minute': 105,
#  'firm': 104,
#  'clingy': 104,
#  'stringy': 103,
#  'visible': 103,
#  'pretty': 102,
#  'oily': 101,
#  'sudsy': 101,
#  'ipa': 101,
#  'bodied': 98,
#  'smoke': 98,
#  'overall': 98,
#  'funk': 98,
#  'chunky': 97,
#  'piney': 97,
#  'nutty': 96,
#  'tint': 94,
#  'streak': 92,
#  'liquid': 92,
#  'active': 91,
#  'crystal': 91,
#  'banana': 91,
#  'steady': 91,
#  'gentle': 91,
#  'lively': 90,
#  'intense': 88,
#  'delicate': 88,
#  'offwhite': 87,
#  'load': 86,
#  'balanced': 85,
#  'milky': 85,
#  'puffy': 85,
#  'present': 85,
#  'dogfish': 84,
#  'poor': 83,
#  'dusty': 83,
#  'healthy': 83,
#  'wine': 83,
#  'quarter': 83,
#  'dank': 83,
#  'grainy': 82,
#  'brilliant': 81,
#  'sediment': 81,
#  'grass': 81,
#  'sweetness': 81,
#  'tangerine': 80,
#  'flat': 80,
#  'tea': 80,
#  'significant': 79,
#  'ish': 78,
#  'second': 78,
#  'hazed': 78,
#  'brewpub': 77,
#  'wood': 77,
#  'minor': 76,
#  'oak': 75,
#  'sparse': 75,
#  'transparent': 74,
#  'vigorous': 74,
#  'smoky': 73,
#  'rye': 73,
#  'snow': 73,
#  'standard': 72,
#  'berry': 72,
#  'viscous': 72,
#  'aromatic': 72,
#  'sand': 72,
#  'musty': 71,
#  'vibrant': 71,
#  'trace': 71,
#  'thing': 70,
#  'substantial': 70,
#  'garnet': 70,
#  'dot': 69,
#  'growler': 69,
#  'bitterness': 69,
#  'non': 69,
#  'dull': 69,
#  'partial': 68,
#  'similar': 67,
#  'hard': 67,
#  'blonde': 67,
#  'unfiltered': 67,
#  'resilient': 66,
#  'tangy': 66,
#  'sugar': 66,
#  'rim': 66,
#  'effervescent': 66,
#  'slim': 66,
#  'alcohol': 66,
#  'couple': 65,
#  'okay': 65,
#  'classic': 65,
#  'barrel': 65,
#  'molasse': 65,
#  'ginger': 64,
#  'coat': 63,
#  'orangey': 63,
#  'scant': 62,
#  'level': 62,
#  'espresso': 62,
#  'clove': 61,
#  'cask': 60,
#  'limited': 60,
#  'staying': 60,
#  'evident': 60,
#  'oil': 59,
#  'plum': 59,
#  'fleeting': 58,
#  'spare': 58,
#  'thank': 57,
#  'sturdy': 57,
#  'tawny': 57,
#  'sandy': 57,
#  'formation': 56,
#  'cereal': 56,
#  'candy': 56,
#  'mellow': 56,
#  'power': 56,
#  'filmy': 56,
#  'whiskey': 56,
#  'toast': 55,
#  'incredible': 55,
#  'fat': 55,
#  'raisin': 55,
#  'close': 55,
#  'outstanding': 55,
#  'rusty': 55,
#  'sharp': 55,
#  'warm': 54,
#  'resin': 54,
#  'ruddy': 54,
#  'lager': 54,
#  'nitro': 54,
#  'peppery': 54,
#  'green': 53,
#  'silky': 53,
#  'grape': 53,
#  'bubbled': 53,
#  'cider': 53,
#  'yield': 53,
#  'biscuit': 53,
#  'delicious': 53,
#  'pumpkin': 52,
#  'crazy': 52,
#  'smokey': 51,
#  'pillow': 51,
#  'easy': 50,
#  'bold': 50,
#  'amberish': 50,
#  'robust': 50,
#  'blackish': 50,
#  'woody': 50,
#  'stone': 49,
#  'turbid': 49,
#  'line': 48,
#  'looking': 48,
#  'bar': 48,
#  'airy': 48,
#  'leave': 48,
#  'egg': 47,
#  'drippy': 47,
#  'lime': 47,
#  'effervescence': 47,
#  'mouth': 47,
#  'strawberry': 46,
#  'cool': 46,
#  'coating': 45,
#  'blueberry': 45,
#  'maple': 45,
#  'buttery': 45,
#  'enormous': 45,
#  'chunk': 44,
#  'tinge': 44,
#  'auburn': 44,
#  'citric': 44,
#  'fast': 44,
#  'source': 44,
#  'respectable': 43,
#  'night': 43,
#  'inky': 43,
#  'lack': 43,
#  'watery': 43,
#  'balance': 42,
#  'new': 42,
#  'burgundy': 42,
#  'porter': 42,
#  'resinous': 42,
#  'crimson': 41,
#  'pepper': 41,
#  'single': 41,
#  'width': 41,
#  'pilsner': 41,
#  'sip': 41,
#  'tone': 41,
#  'swirl': 41,
#  'coriander': 40,
#  'curtain': 40,
#  'herb': 40,
#  'mix': 40,
#  'rust': 40,
#  'unique': 40,
#  'slick': 40,
#  'noticeable': 40,
#  'brief': 39,
#  'fading': 39,
#  'whispy': 39,
#  'old': 39,
#  'giant': 39,
#  'streaky': 38,
#  'peachy': 38,
#  'taster': 38,
#  'base': 38,
#  'nut': 38,
#  'oatmeal': 38,
#  'darker': 37,
#  'consistency': 37,
#  'strand': 37,
#  'brewer': 37,
#  'clumpy': 37,
#  'surprising': 37,
#  'spider': 37,
#  'maroon': 37,
#  'musk': 36,
#  'creme': 36,
#  'pungent': 36,
#  'soap': 36,
#  'end': 36,
#  'existent': 36,
#  'character': 36,
#  'settle': 36,
#  'sure': 36,
#  'treacle': 36,
#  'wall': 35,
#  'champagne': 35,
#  'mango': 35,
#  'consistent': 35,
#  'bad': 35,
#  'cloud': 35,
#  'odd': 35,
#  'thinnish': 34,
#  'biscuity': 34,
#  'broken': 34,
#  'different': 34,
#  'pic': 34,
#  'saison': 34,
#  'cloudiness': 34,
#  'chalice': 34,
#  'almond': 34,
#  'darkest': 34,
#  'web': 34,
#  'syrup': 34,
#  'rough': 33,
#  'blend': 33,
#  'sort': 33,
#  'stay': 33,
#  'mid': 33,
#  'summer': 33,
#  'residual': 33,
#  'dissipation': 33,
#  'stream': 33,
#  'kind': 33,
#  'blood': 33,
#  'hay': 33,
#  'laced': 33,
#  'bead': 33,
#  'tasty': 33,
#  'toasty': 33,
#  'inside': 33,
#  'day': 33,
#  'island': 32,
#  'soda': 32,
#  'med': 32,
#  'orangy': 32,
#  'goblet': 32,
#  'stark': 32,
#  'durable': 32,
#  'cappuccino': 32,
#  'sample': 32,
#  'transient': 32,
#  'drinking': 31,
#  'refreshing': 31,
#  'label': 31,
#  'home': 31,
#  'barley': 31,
#  'profile': 31,
#  'transparency': 31,
#  'melon': 31,
#  'drink': 31,
#  'ounce': 31,
#  'blond': 31,
#  'rose': 30,
#  'taupe': 30,
#  'vinous': 30,
#  'ester': 30,
#  'adequate': 30,
#  'gray': 30,
#  'wet': 30,
#  'lacingtaste': 30,
#  'grayish': 30,
#  'sugary': 30,
#  'ripe': 30,
#  'coconut': 30,
#  'type': 30,
#  'retentive': 30,
#  'latte': 30,
#  'retain': 30,
#  'motor': 30,
#  'shade': 30,
#  'date': 29,
#  'brass': 29,
#  'webs': 29,
#  'boozy': 29,
#  'true': 29,
#  'lactic': 29,
#  'bubblegum': 29,
#  'colour': 29,
#  'toasted': 29,
#  'nonic': 29,
#  'normal': 29,
#  'entire': 29,
#  'cover': 29,
#  'pattern': 28,
#  'splotch': 28,
#  'carb': 28,
#  'cranberry': 28,
#  'mug': 28,
#  'velvety': 28,
#  'lazy': 28,
#  'plentiful': 28,
#  'root': 28,
#  'crown': 28,
#  'meringue': 28,
#  'exceptional': 28,
#  'floatie': 28,
#  'shell': 27,
#  'leather': 27,
#  'reasonable': 27,
#  'chill': 27,
#  'vinegar': 27,
#  'clouded': 27,
#  'wheaty': 27,
#  'presence': 27,
#  'cold': 27,
#  'acidic': 27,
#  'quality': 27,
#  'trail': 27,
#  'rum': 27,
#  'sourness': 26,
#  'purplish': 26,
#  'cinnamon': 26,
#  'halo': 26,
#  'prominent': 26,
#  'careful': 26,
#  'mixed': 26,
#  'imperial': 26,
#  'bouquet': 26,
#  'shiny': 25,
#  'butter': 25,
#  'stuff': 25,
#  'appealing': 25,
#  'butterscotch': 25,
#  'citru': 25,
#  'fuzzy': 25,
#  'chewy': 25,
#  'earth': 25,
#  'whit': 25,
#  'wit': 25,
#  'result': 25,
#  'festival': 25,
#  'grey': 25,
#  'brewing': 24,
#  'wake': 24,
#  'pil': 24,
#  'center': 24,
#  'tartness': 24,
#  'bomber': 24,
#  'splotchy': 24,
#  'simple': 24,
#  'pace': 24,
#  'right': 24,
#  'middle': 24,
#  'room': 24,
#  'copious': 24,
#  'spruce': 24,
#  'water': 24,
#  'messy': 24,
#  'hefe': 24,
#  'ice': 24,
#  'band': 24,
#  'year': 23,
#  'peat': 23,
#  'whisp': 23,
#  'superb': 23,
#  'zesty': 23,
#  'prune': 23,
#  'abundant': 23,
#  'powerful': 23,
#  'fizzle': 23,
#  'sizable': 23,
#  'compact': 22,
#  'density': 22,
#  'dipa': 22,
#  'uniform': 22,
#  'pear': 22,
#  'pub': 22,
#  'lacingsmell': 22,
#  'fruitiness': 22,
#  'strange': 22,
#  'stiff': 22,
#  'skim': 22,
#  'antique': 21,
#  'drinkable': 21,
#  'depth': 21,
#  'glasss': 21,
#  'point': 21,
#  'corn': 21,
#  'centimetre': 21,
#  'extensive': 21,
#  'appropriate': 21,
#  'tanned': 21,
#  'umber': 21,
#  'hazelnut': 21,
#  'lacearoma': 21,
#  'cascade': 21,
#  'definite': 20,
#  'float': 20,
#  'rise': 20,
#  'tasting': 20,
#  'passion': 20,
#  'sunset': 20,
#  'start': 20,
#  'rest': 20,
#  'blanket': 20,
#  'version': 20,
#  'usual': 20,
#  'flowery': 20,
#  'skin': 20,
#  'world': 20,
#  'uneven': 20,
#  'ink': 20,
#  'session': 20,
#  'sea': 20,
#  'regular': 20,
#  'haziness': 20,
#  'reminiscent': 20,
#  'wild': 20,
#  'english': 19,
#  'ridiculous': 19,
#  'fragrant': 19,
#  'release': 19,
#  'apparent': 19,
#  'apricot': 19,
#  'ebony': 19,
#  'duration': 19,
#  'webby': 19,
#  'speck': 19,
#  'booze': 19,
#  'rosy': 19,
#  'taproom': 19,
#  'lumpy': 18,
#  'background': 18,
#  'moment': 18,
#  'barnyard': 18,
#  'intricate': 18,
#  'doughy': 18,
#  'assertive': 18,
#  'considerable': 18,
#  'effect': 18,
#  'enjoyable': 18,
#  'gigantic': 18,
#  'special': 18,
#  'belgium': 18,
#  'midnight': 18,
#  'sud': 18,
#  'clot': 18,
#  'neat': 18,
#  'course': 18,
#  'coarse': 18,
#  'stable': 18,
#  'complete': 18,
#  'darkish': 18,
#  'descent': 18,
#  'clearish': 17,
#  'house': 17,
#  'particle': 17,
#  'clump': 17,
#  'chalky': 17,
#  'noble': 17,
#  'coloured': 17,
#  'constant': 17,
#  'class': 17,
#  'milkshake': 17,
#  'linger': 17,
#  'covering': 17,
#  'orangeish': 17,
#  'foggy': 17,
#  'german': 17,
#  'wavy': 17,
#  'straight': 17,
#  'sign': 17,
#  'fudge': 17,
#  'man': 17,
#  'syrupy': 17,
#  'lacework': 17,
#  'lemony': 17,
#  'gravity': 16,
#  'longevity': 16,
#  'aftertaste': 16,
#  'watermelon': 16,
#  'traditional': 16,
#  'penny': 16,
#  'tad': 16,
#  'fig': 16,
#  'phenomenal': 16,
#  'heady': 16,
#  'cracker': 16,
#  'glow': 16,
#  'peanut': 16,
#  'voluminous': 16,
#  'impression': 16,
#  'review': 16,
#  'barleywine': 16,
#  'distinct': 16,
#  'hot': 16,
#  'shaker': 16,
#  'dash': 16,
#  'laceflavor': 16,
#  'sexy': 15,
#  'vanishe': 15,
#  'spiderweb': 15,
#  'layered': 15,
#  'veil': 15,
#  'random': 15,
#  'blackberry': 15,
#  'bunch': 15,
#  'spritzy': 15,
#  'nail': 15,
#  'lush': 15,
#  'spongy': 15,
#  'disc': 15,
#  'disappointing': 15,
#  'grapefruity': 15,
#  'biege': 15,
#  'mountainous': 15,
#  'roastiness': 15,
#  'sheer': 15,
#  'topping': 15,
#  'cone': 15,
#  'ultra': 15,
#  'lemongrass': 15,
#  'cookie': 15,
#  'dough': 15,
#  'redish': 15,
#  'sustained': 15,
#  'difficult': 14,
#  'ringer': 14,
#  'ugly': 14,
#  'sheen': 14,
#  'slippery': 14,
#  'copperish': 14,
#  'tremendous': 14,
#  'paper': 14,
#  'presentable': 14,
#  'favorite': 14,
#  'impressed': 14,
#  'rate': 14,
#  'gobs': 14,
#  'behindsmell': 14,
#  'basic': 14,
#  'double': 14,
#  'acetic': 14,
#  'sporadic': 14,
#  'tanish': 14,
#  'glossy': 14,
#  'acid': 14,
#  'weird': 14,
#  'thickness': 14,
#  'hell': 14,
#  'linen': 14,
#  'ribbon': 13,
#  'peel': 13,
#  'plastic': 13,
#  'froathy': 13,
#  'wife': 13,
#  'sparkling': 13,
#  'fluid': 13,
#  'cheese': 13,
#  'craggy': 13,
#  'luscious': 13,
#  'spray': 13,
#  'sienna': 13,
#  'dollop': 13,
#  'pleasing': 13,
#  'action': 13,
#  'bartender': 13,
#  'combination': 13,
#  'hearty': 13,
#  'flower': 13,
#  'magenta': 13,
#  'final': 13,
#  'sizeable': 13,
#  'pop': 13,
#  'lemonade': 13,
#  'extreme': 13,
#  'cakey': 12,
#  'local': 12,
#  'delightful': 12,
#  'dusting': 12,
#  'billowy': 12,
#  'tab': 12,
#  'hoppiness': 12,
#  'shy': 12,
#  'spiced': 12,
#  'handed': 12,
#  'monster': 12,
#  'peak': 12,
#  'score': 12,
#  'late': 12,
#  'swath': 12,
#  'surprise': 12,
#  'think': 12,
#  'american': 12,
#  'shoulder': 12,
#  'skiff': 12,
#  'fact': 12,
#  'thumb': 12,
#  'fall': 12,
#  'overripe': 12,
#  'wave': 12,
#  'subsequent': 12,
#  'aged': 12,
#  'chili': 12,
#  'insane': 12,
#  'fun': 12,
#  'clung': 12,
#  'meat': 12,
#  'walnut': 12,
#  'farmhouse': 12,
#  'salty': 12,
#  'terrific': 12,
#  'city': 12,
#  'unclear': 12,
#  'hefty': 12,
#  'ridge': 12,
#  'marshmallow': 12,
#  'elegant': 12,
#  'deal': 12,
#  'port': 12,
#  'frosty': 12,
#  'signature': 12,
#  'particulate': 12,
#  'oaky': 12,
#  'rope': 12,
#  'minty': 12,
#  'baby': 12,
#  'round': 12,
#  'brick': 11,
#  'muddled': 11,
#  'wise': 11,
#  'currant': 11,
#  'full': 11,
#  'superior': 11,
#  'characteristic': 11,
#  'vision': 11,
#  'pencil': 11,
#  'pearl': 11,
#  'centimeter': 11,
#  'iced': 11,
#  'miniscule': 11,
#  'location': 11,
#  'place': 11,
#  'rind': 11,
#  'cotton': 11,
#  'prickly': 11,
#  'magnificent': 11,
#  'whiff': 11,
#  'lattice': 11,
#  'cellar': 11,
#  'brandy': 11,
#  'darkness': 11,
#  'fleck': 11,
#  'pile': 11,
#  'weight': 11,
#  'crater': 11,
#  'tobacco': 11,
#  'offering': 11,
#  'fan': 11,
#  'abv': 11,
#  'grandview': 11,
#  'foaming': 11,
#  'churchkey': 11,
#  'lived': 11,
#  'brisk': 11,
#  'licorice': 11,
#  'persistant': 11,
#  'tripel': 11,
#  'wide': 11,
#  'multi': 11,
#  'duvel': 11,
#  'punch': 11,
#  'lactose': 11,
#  'friend': 11,
#  'pool': 11,
#  'oat': 11,
#  'papaya': 10,
#  'glassa': 10,
#  'teku': 10,
#  'yellowed': 10,
#  'spectacular': 10,
#  'work': 10,
#  'proper': 10,
#  'forward': 10,
#  'lite': 10,
#  'rbwg': 10,
#  'potent': 10,
#  'floater': 10,
#  'soy': 10,
#  'glasssmell': 10,
#  'batch': 10,
#  'concentrated': 10,
#  'rating': 10,
#  'mint': 10,
#  'pit': 10,
#  'hand': 10,
#  'mineral': 10,
#  'bretty': 10,
#  'future': 10,
#  'handsome': 10,
#  'drain': 10,
#  'height': 10,
#  'beauty': 10,
#  'pinky': 10,
#  'scotch': 10,
#  'mud': 10,
#  'volume': 10,
#  'stellar': 10,
#  'witha': 10,
#  'beginning': 10,
#  'burst': 10,
#  'java': 10,
#  'neon': 10,
#  'whtie': 10,
#  'sunshine': 10,
#  'notable': 10,
#  'raw': 10,
#  'cup': 10,
#  'bite': 10,
#  'flavour': 10,
#  'micro': 10,
#  'permanent': 10,
#  'table': 9,
#  'min': 9,
#  'ashy': 9,
#  'ass': 9,
#  'nonexistent': 9,
#  'greyish': 9,
#  'gusher': 9,
#  'nutmeg': 9,
#  'party': 9,
#  'glob': 9,
#  'alive': 9,
#  'dead': 9,
#  'original': 9,
#  'element': 9,
#  'blue': 9,
#  'unusual': 9,
#  ...}

# %%
taste_dict
# Out:
# {'sweet': 6637,
#  'light': 4156,
#  'chocolate': 2641,
#  'bitter': 2607,
#  'citrus': 2517,
#  'fruit': 2504,
#  'medium': 2381,
#  'nose': 2100,
#  'coffee': 2048,
#  'note': 1936,
#  'smooth': 1723,
#  'similar': 1588,
#  'caramel': 1529,
#  'roasted': 1497,
#  'dark': 1487,
#  'dry': 1472,
#  'fruity': 1400,
#  'tart': 1384,
#  'big': 1328,
#  'bodied': 1250,
#  'bitterness': 1204,
#  'sour': 1199,
#  'lot': 1173,
#  'strong': 1115,
#  'spice': 1089,
#  'mild': 1071,
#  'pine': 1054,
#  'rich': 1047,
#  'grapefruit': 1027,
#  'yeast': 1022,
#  'profile': 1005,
#  'vanilla': 977,
#  'sweetness': 952,
#  'earthy': 950,
#  'floral': 910,
#  'lemon': 871,
#  'balanced': 858,
#  'alcohol': 832,
#  'wheat': 820,
#  'spicy': 807,
#  'clean': 801,
#  'moderate': 757,
#  'crisp': 732,
#  'grain': 730,
#  'slight': 722,
#  'heavy': 690,
#  'cherry': 672,
#  'tropical': 670,
#  'bourbon': 666,
#  'creamy': 649,
#  'mid': 637,
#  'complex': 629,
#  'hint': 624,
#  'roasty': 617,
#  'bready': 595,
#  'bread': 590,
#  'roast': 578,
#  'orange': 574,
#  'herbal': 537,
#  'honey': 530,
#  'fresh': 529,
#  'sugar': 494,
#  'balance': 489,
#  'toffee': 488,
#  'solid': 478,
#  'oak': 443,
#  'cocoa': 442,
#  'pale': 423,
#  'soft': 413,
#  'overall': 411,
#  'juicy': 407,
#  'subtle': 403,
#  'grass': 390,
#  'grassy': 388,
#  'smoke': 386,
#  'apple': 381,
#  'strength': 377,
#  'white': 376,
#  'pepper': 372,
#  'brown': 371,
#  'banana': 362,
#  'funk': 355,
#  'touch': 354,
#  'interesting': 354,
#  'nutty': 348,
#  'character': 340,
#  'pleasant': 340,
#  'initial': 339,
#  'refreshing': 336,
#  'citrusy': 335,
#  'belgian': 328,
#  'decent': 327,
#  'mix': 313,
#  'bittersweet': 306,
#  'rye': 303,
#  'pineapple': 299,
#  'thick': 297,
#  'excellent': 296,
#  'bright': 294,
#  'wood': 291,
#  'raspberry': 282,
#  'thin': 281,
#  'piney': 281,
#  'grainy': 275,
#  'end': 275,
#  'berry': 274,
#  'easy': 267,
#  'clove': 266,
#  'yeasty': 265,
#  'huge': 260,
#  'wine': 259,
#  'molasse': 256,
#  'ale': 253,
#  'biscuit': 243,
#  'funky': 242,
#  'raisin': 241,
#  'sip': 239,
#  'bud': 235,
#  'plenty': 234,
#  'peach': 234,
#  'peppery': 233,
#  'resin': 232,
#  'milk': 231,
#  'barrel': 227,
#  'tartness': 225,
#  'background': 224,
#  'mouth': 220,
#  'unique': 219,
#  'present': 218,
#  'grape': 217,
#  'way': 216,
#  'black': 215,
#  'smoky': 213,
#  'woody': 212,
#  'faint': 209,
#  'toast': 209,
#  'pumpkin': 208,
#  'low': 208,
#  'aftertaste': 201,
#  'stout': 200,
#  'ester': 199,
#  'ton': 193,
#  'middle': 191,
#  'sharp': 190,
#  'bold': 190,
#  'intense': 189,
#  'sticky': 188,
#  'deep': 188,
#  'candy': 187,
#  'delicious': 184,
#  'suit': 183,
#  'brew': 181,
#  'tangy': 180,
#  'whiskey': 176,
#  'blend': 176,
#  'peel': 175,
#  'different': 175,
#  'tasty': 175,
#  'nut': 175,
#  'ipa': 174,
#  'acidic': 171,
#  'straw': 168,
#  'boozy': 166,
#  'fruitiness': 165,
#  'smokey': 165,
#  'dominant': 164,
#  'mellow': 164,
#  'long': 162,
#  'presence': 160,
#  'style': 160,
#  'red': 159,
#  'earth': 158,
#  'wonderful': 157,
#  'hay': 157,
#  'complexity': 156,
#  'earthiness': 155,
#  'tangerine': 155,
#  'amazing': 153,
#  'juice': 152,
#  'maple': 152,
#  'awesome': 152,
#  'perfect': 151,
#  'enjoyable': 150,
#  'green': 150,
#  'toasty': 149,
#  'booze': 148,
#  'tongue': 148,
#  'average': 147,
#  'ginger': 146,
#  'quality': 142,
#  'drinkable': 141,
#  'dank': 141,
#  'coconut': 141,
#  'tone': 139,
#  'high': 138,
#  'mango': 138,
#  'dough': 137,
#  'robust': 137,
#  'med': 136,
#  'melon': 135,
#  'lace': 134,
#  'coriander': 134,
#  'semi': 134,
#  'sourness': 130,
#  'lime': 130,
#  'depth': 130,
#  'cracker': 129,
#  'noticeable': 129,
#  'blueberry': 128,
#  'bad': 126,
#  'bite': 125,
#  'tea': 121,
#  'cereal': 120,
#  'biscuity': 119,
#  'fantastic': 119,
#  'backbone': 119,
#  'super': 118,
#  'rind': 118,
#  'bubblegum': 117,
#  'barley': 117,
#  'lager': 114,
#  'zest': 114,
#  'herb': 112,
#  'real': 111,
#  'cream': 111,
#  'plum': 109,
#  'acidity': 108,
#  'thing': 108,
#  'hoppiness': 107,
#  'upfront': 106,
#  'resinous': 106,
#  'glass': 105,
#  'syrup': 105,
#  'porter': 105,
#  'watery': 105,
#  'chewy': 103,
#  'vinous': 102,
#  'vinegar': 101,
#  'sugary': 101,
#  'lemony': 99,
#  'prominent': 99,
#  'hearty': 97,
#  'distinct': 97,
#  'load': 97,
#  'base': 97,
#  'stone': 95,
#  'typical': 92,
#  'citric': 92,
#  'classic': 92,
#  'time': 91,
#  'cinnamon': 90,
#  'strawberry': 90,
#  'doughy': 89,
#  'spiciness': 89,
#  'metallic': 89,
#  'lactic': 89,
#  'warm': 87,
#  'dusty': 87,
#  'combination': 86,
#  'buttery': 85,
#  'hot': 85,
#  'slick': 84,
#  'element': 84,
#  'butter': 84,
#  'licorice': 84,
#  'heat': 84,
#  'gentle': 84,
#  'layer': 82,
#  'saison': 81,
#  'drinking': 80,
#  'mineral': 79,
#  'musty': 79,
#  'wheaty': 78,
#  'quick': 78,
#  'undertone': 78,
#  'kick': 78,
#  'small': 78,
#  'linger': 77,
#  'definite': 76,
#  'sure': 75,
#  'espresso': 75,
#  'oily': 75,
#  'fig': 74,
#  'corn': 74,
#  'lovely': 74,
#  'type': 74,
#  'peat': 73,
#  'delicate': 73,
#  'lively': 73,
#  'peanut': 72,
#  'bean': 72,
#  'drinkability': 72,
#  'bubble': 72,
#  'simple': 71,
#  'blackberry': 71,
#  'overwhelming': 70,
#  'dominate': 70,
#  'leg': 70,
#  'start': 69,
#  'minimal': 69,
#  'salty': 69,
#  'pleasing': 69,
#  'pilsner': 69,
#  'backing': 69,
#  'right': 68,
#  'rum': 68,
#  'tobacco': 67,
#  'pear': 67,
#  'stuff': 67,
#  'prune': 67,
#  'match': 67,
#  'silky': 67,
#  'weak': 66,
#  'impressive': 66,
#  'citru': 66,
#  'tad': 65,
#  'reminiscent': 65,
#  'nuttiness': 64,
#  'oatmeal': 64,
#  'mint': 64,
#  'pie': 64,
#  'consistent': 64,
#  'flower': 64,
#  'ground': 64,
#  'velvety': 64,
#  'characteristic': 64,
#  'abv': 63,
#  'punch': 63,
#  'zesty': 63,
#  'barnyard': 63,
#  'syrupy': 63,
#  'noble': 62,
#  'date': 62,
#  'spot': 62,
#  'firm': 61,
#  'length': 61,
#  'level': 60,
#  'fine': 60,
#  'incredible': 60,
#  'summer': 60,
#  'astringent': 60,
#  'true': 60,
#  'apparent': 60,
#  'forward': 59,
#  'leather': 59,
#  'spiced': 59,
#  'outstanding': 59,
#  'clear': 58,
#  'lactose': 58,
#  'kind': 58,
#  'component': 57,
#  'roastiness': 57,
#  'oaky': 57,
#  'flowery': 57,
#  'hard': 56,
#  'oat': 56,
#  'old': 56,
#  'salt': 55,
#  'hazelnut': 54,
#  'toasted': 53,
#  'ripe': 53,
#  'english': 53,
#  'skin': 53,
#  'mocha': 52,
#  'swallow': 52,
#  'assertive': 51,
#  'subdued': 51,
#  'resiny': 50,
#  'beautiful': 50,
#  'spruce': 50,
#  'smokiness': 50,
#  'weird': 49,
#  'edge': 49,
#  'burst': 49,
#  'cranberry': 49,
#  'pronounced': 49,
#  'short': 49,
#  'passion': 48,
#  'aspect': 48,
#  'gum': 48,
#  'acid': 47,
#  'worth': 47,
#  'brandy': 47,
#  'wet': 47,
#  'session': 47,
#  'sort': 47,
#  'wise': 46,
#  'rounded': 46,
#  'flat': 46,
#  'powder': 46,
#  'evident': 46,
#  'mirror': 46,
#  'aggressive': 46,
#  'odd': 46,
#  'pretty': 46,
#  'port': 45,
#  'flavorful': 45,
#  'ash': 45,
#  'dryness': 45,
#  'ring': 45,
#  'anise': 45,
#  'experience': 45,
#  'impression': 45,
#  'nutmeg': 44,
#  'cool': 44,
#  'milky': 44,
#  'water': 44,
#  'powerful': 44,
#  'warming': 43,
#  'cake': 43,
#  'bottle': 43,
#  'strange': 43,
#  'late': 43,
#  'accent': 43,
#  'amber': 42,
#  'lemongrass': 42,
#  'leafy': 42,
#  'wild': 42,
#  'close': 41,
#  'pil': 41,
#  'acetic': 41,
#  'butterscotch': 41,
#  'crust': 41,
#  'golden': 41,
#  'dense': 41,
#  'mixed': 41,
#  'traditional': 40,
#  'scotch': 40,
#  'cider': 40,
#  'pure': 40,
#  'medicinal': 40,
#  'natural': 40,
#  'almond': 40,
#  'round': 40,
#  'delightful': 39,
#  'warmth': 39,
#  'surprising': 39,
#  'soapy': 39,
#  'german': 39,
#  'crackery': 39,
#  'large': 39,
#  'term': 38,
#  'grapefruity': 38,
#  'cold': 38,
#  'main': 38,
#  'aromatic': 37,
#  'overtone': 37,
#  'brownie': 37,
#  'chalky': 37,
#  'chili': 37,
#  'satisfying': 37,
#  'harsh': 37,
#  'alcoholic': 36,
#  'marshmallow': 36,
#  'tannic': 36,
#  'raw': 36,
#  'american': 36,
#  'retention': 36,
#  'standard': 36,
#  'cookie': 35,
#  'new': 35,
#  'onion': 35,
#  'department': 35,
#  'actual': 35,
#  'phenolic': 35,
#  'point': 34,
#  'hit': 34,
#  'imperial': 34,
#  'authentic': 34,
#  'unusual': 33,
#  'vegetal': 33,
#  'favorite': 33,
#  'cascade': 33,
#  'bomb': 33,
#  'beige': 33,
#  'potent': 33,
#  'exceptional': 33,
#  'tannin': 33,
#  'oil': 33,
#  'second': 33,
#  'bland': 32,
#  'bittering': 32,
#  'perfume': 32,
#  'dose': 32,
#  'surprise': 32,
#  'ish': 32,
#  'meat': 32,
#  'goodness': 32,
#  'tap': 32,
#  'farmhouse': 32,
#  'blast': 32,
#  'cheese': 32,
#  'pungent': 31,
#  'cloudy': 31,
#  'coat': 31,
#  'fluffy': 31,
#  'fizzy': 31,
#  'yellow': 31,
#  'aged': 31,
#  'effervescent': 31,
#  'sweetish': 30,
#  'minty': 30,
#  'sense': 30,
#  'hopping': 30,
#  'mixture': 30,
#  'passionfruit': 30,
#  'barleywine': 30,
#  'sensation': 30,
#  'addition': 30,
#  'breadiness': 30,
#  'modest': 29,
#  'version': 29,
#  'watermelon': 29,
#  'treacle': 29,
#  'yield': 28,
#  'apricot': 28,
#  'creaminess': 28,
#  'minor': 28,
#  'residual': 28,
#  'fudge': 28,
#  'drink': 28,
#  'massive': 28,
#  'combo': 27,
#  'ashy': 27,
#  'burn': 27,
#  'predominant': 27,
#  'booziness': 27,
#  'muted': 27,
#  'citra': 27,
#  'underlying': 27,
#  'fun': 26,
#  'tripel': 26,
#  'artificial': 26,
#  'fair': 26,
#  'yummy': 26,
#  'distinctive': 26,
#  'superb': 26,
#  'prevalent': 26,
#  'lean': 26,
#  'intensity': 26,
#  'score': 26,
#  'hefeweizen': 26,
#  'dust': 26,
#  'explosion': 26,
#  'guava': 26,
#  'savory': 25,
#  'yeastiness': 25,
#  'early': 25,
#  'general': 25,
#  'currant': 25,
#  'cola': 25,
#  'leave': 25,
#  'bacon': 25,
#  'hefe': 25,
#  'full': 24,
#  'dipa': 24,
#  'stick': 24,
#  'fade': 24,
#  'tiny': 24,
#  'smelling': 24,
#  'rest': 24,
#  'wave': 24,
#  'line': 24,
#  'familiar': 24,
#  'papaya': 24,
#  'feeling': 24,
#  'sessionable': 23,
#  'hazy': 23,
#  'carmel': 23,
#  'bar': 23,
#  'rustic': 23,
#  'grassiness': 23,
#  'foamy': 23,
#  'overripe': 23,
#  'dirty': 23,
#  'laceflavor': 23,
#  'effect': 22,
#  'straight': 22,
#  'blanket': 22,
#  'obvious': 22,
#  'blood': 22,
#  'day': 22,
#  'charcoal': 22,
#  'deal': 22,
#  'wit': 22,
#  'crispness': 22,
#  'blonde': 22,
#  'phenol': 22,
#  'substantial': 22,
#  'okay': 21,
#  'bouquet': 21,
#  'dankness': 21,
#  'hoppi': 21,
#  'coating': 21,
#  'double': 21,
#  'roll': 21,
#  'liquor': 21,
#  'charred': 21,
#  'cleanser': 21,
#  'soda': 21,
#  'liquid': 21,
#  'prickly': 21,
#  'orangey': 21,
#  'intriguing': 21,
#  'ice': 21,
#  'surprised': 21,
#  'whisky': 20,
#  'normal': 20,
#  'pink': 20,
#  'juniper': 20,
#  'ample': 20,
#  'root': 20,
#  'bubbly': 20,
#  'test': 20,
#  'sea': 20,
#  'mosaic': 20,
#  'midw': 20,
#  'beginning': 20,
#  'detectable': 20,
#  'job': 20,
#  'course': 20,
#  'crazy': 20,
#  'draw': 20,
#  'decadent': 19,
#  'pecan': 19,
#  'vegetable': 19,
#  'thank': 19,
#  'woodsy': 19,
#  'graininess': 19,
#  'astringency': 19,
#  'carb': 19,
#  'soy': 19,
#  'disappointing': 19,
#  'nectarine': 19,
#  'char': 19,
#  'identical': 19,
#  'smoothness': 19,
#  'treat': 19,
#  'face': 19,
#  'gooseberry': 19,
#  'lavender': 19,
#  'baker': 19,
#  'effervescence': 19,
#  'additional': 18,
#  'regular': 18,
#  'appealing': 18,
#  'oats': 18,
#  'candi': 18,
#  'non': 18,
#  'crystal': 18,
#  'lacto': 18,
#  'variety': 18,
#  'viscous': 18,
#  'peachy': 18,
#  'blind': 18,
#  'straightforward': 18,
#  'kiwi': 18,
#  'able': 18,
#  'lush': 18,
#  'soap': 18,
#  'cleansing': 18,
#  'particular': 18,
#  'gold': 18,
#  'transition': 17,
#  'cucumber': 17,
#  'spectacular': 17,
#  'chocolaty': 17,
#  'liquorice': 17,
#  'noticable': 17,
#  'seed': 17,
#  'semisweet': 17,
#  'lip': 17,
#  'fatigue': 17,
#  'snappy': 17,
#  'champagne': 17,
#  'minute': 17,
#  'abundant': 17,
#  'significant': 17,
#  'cedar': 17,
#  'inviting': 17,
#  'gin': 17,
#  'quenching': 17,
#  'hibiscus': 17,
#  'terrific': 17,
#  'mimic': 16,
#  'milder': 16,
#  'heft': 16,
#  'baked': 16,
#  'lack': 16,
#  'diacetyl': 16,
#  'difference': 16,
#  'oxidation': 16,
#  'weed': 16,
#  'nib': 16,
#  'pithy': 16,
#  'holiday': 16,
#  'year': 16,
#  'certain': 16,
#  'rice': 16,
#  'hand': 16,
#  'healthy': 16,
#  'shot': 16,
#  'brief': 16,
#  'pop': 16,
#  'entire': 16,
#  'measure': 16,
#  'mind': 16,
#  'sage': 16,
#  'unexpected': 15,
#  'dull': 15,
#  'trace': 15,
#  'spicey': 15,
#  'piny': 15,
#  'remarkable': 15,
#  'cognac': 15,
#  'gingerbread': 15,
#  'bock': 15,
#  'ball': 15,
#  'bone': 15,
#  'needle': 15,
#  'brewery': 15,
#  'richness': 15,
#  'example': 15,
#  'aging': 15,
#  'kinda': 15,
#  'wrecker': 15,
#  'alot': 15,
#  'sauce': 15,
#  'cloying': 15,
#  'funkiness': 15,
#  'backend': 15,
#  'weight': 15,
#  'fact': 15,
#  'jam': 15,
#  'husky': 15,
#  'winter': 15,
#  'irish': 15,
#  'forefront': 15,
#  'spritzy': 15,
#  'rush': 15,
#  'pit': 15,
#  'lasting': 15,
#  'half': 14,
#  'enticing': 14,
#  'hope': 14,
#  'tinge': 14,
#  'pumpernickel': 14,
#  'brisk': 14,
#  'abundance': 14,
#  'basic': 14,
#  'special': 14,
#  'allspice': 14,
#  'lead': 14,
#  'assault': 14,
#  'power': 14,
#  'thirst': 14,
#  'vibrant': 14,
#  'cask': 14,
#  'par': 14,
#  'personal': 14,
#  'hidden': 14,
#  'tasting': 14,
#  'progression': 14,
#  'nature': 14,
#  'usual': 14,
#  'lambic': 14,
#  'glad': 14,
#  'woodiness': 14,
#  'equal': 13,
#  'basement': 13,
#  'world': 13,
#  'feature': 13,
#  'french': 13,
#  'walnut': 13,
#  'single': 13,
#  'tree': 13,
#  'support': 13,
#  'duration': 13,
#  'herbaceous': 13,
#  'insane': 13,
#  'nuance': 13,
#  'twang': 13,
#  'punchy': 13,
#  'drier': 13,
#  'amount': 13,
#  'dessert': 13,
#  'opinion': 13,
#  'lingering': 13,
#  'fall': 13,
#  'secondary': 13,
#  'winner': 13,
#  'final': 13,
#  'guy': 13,
#  'peppermint': 13,
#  'immediate': 13,
#  'range': 13,
#  'fan': 13,
#  'impressed': 13,
#  'filling': 13,
#  'sourdough': 12,
#  'dimension': 12,
#  'work': 12,
#  'estery': 12,
#  'neutral': 12,
#  'rosemary': 12,
#  'man': 12,
#  'nutella': 12,
#  'stale': 12,
#  'pucker': 12,
#  'dubbel': 12,
#  'extreme': 12,
#  'copper': 12,
#  'marmalade': 12,
#  'mustiness': 12,
#  'suggestion': 12,
#  'ingredient': 12,
#  'dimensional': 12,
#  'chamomile': 12,
#  'offering': 12,
#  'piss': 12,
#  'sturdy': 12,
#  'hefty': 12,
#  'peppercorn': 12,
#  'cut': 12,
#  'blossom': 12,
#  'play': 12,
#  'chipotle': 12,
#  'unpleasant': 12,
#  'overwhelm': 12,
#  'tingle': 12,
#  'price': 12,
#  'welcome': 12,
#  'rough': 12,
#  'food': 12,
#  'cone': 12,
#  'couple': 12,
#  'brewer': 11,
#  'gritty': 11,
#  'juiciness': 11,
#  'key': 11,
#  'dance': 11,
#  'change': 11,
#  'haystack': 11,
#  'creme': 11,
#  'primary': 11,
#  'dynamic': 11,
#  'description': 11,
#  'highlight': 11,
#  'possible': 11,
#  'content': 11,
#  'exotic': 11,
#  'skunky': 11,
#  'unsweetened': 11,
#  'bunch': 11,
#  'creamsicle': 11,
#  'rubber': 11,
#  'fruittiness': 11,
#  'horse': 11,
#  'stickiness': 11,
#  'zing': 11,
#  'layered': 11,
#  'ease': 11,
#  'dead': 11,
#  'phenomenal': 11,
#  'cardamom': 11,
#  'raisiny': 11,
#  'freshness': 11,
#  'plastic': 11,
#  'spicing': 11,
#  'cardboard': 11,
#  'beet': 11,
#  'winey': 11,
#  'difficult': 11,
#  'acrid': 11,
#  'saaz': 11,
#  'chardonnay': 11,
#  'house': 11,
#  'original': 11,
#  'extra': 11,
#  'signature': 11,
#  'restrained': 11,
#  'rating': 11,
#  'grapey': 10,
#  'kiss': 10,
#  'spearmint': 10,
#  'olive': 10,
#  'tight': 10,
#  'pulp': 10,
#  'similiar': 10,
#  'munich': 10,
#  'twist': 10,
#  'plus': 10,
#  'belgium': 10,
#  'lychee': 10,
#  'flaw': 10,
#  'throat': 10,
#  'tremendous': 10,
#  'appropriate': 10,
#  'ready': 10,
#  'cat': 10,
#  'drinker': 10,
#  'chemical': 10,
#  'powering': 10,
#  'age': 10,
#  'sourish': 10,
#  'airy': 10,
#  'tan': 10,
#  'popcorn': 10,
#  'mushroom': 10,
#  'entry': 10,
#  'dirt': 10,
#  'complimentary': 10,
#  'habanero': 10,
#  'factor': 10,
#  'potato': 10,
#  'dandelion': 10,
#  'boot': 10,
#  'impact': 10,
#  'notable': 10,
#  'mash': 10,
#  'complete': 10,
#  'lemonade': 10,
#  'result': 10,
#  'room': 10,
#  'bourbony': 10,
#  'killer': 10,
#  'doppelbock': 10,
#  'nuts': 10,
#  'flavour': 10,
#  'pilsener': 10,
#  'case': 10,
#  'emphasis': 10,
#  'adjunct': 10,
#  'cotton': 10,
#  'luscious': 10,
#  'leathery': 10,
#  'hue': 9,
#  'ride': 9,
#  'stage': 9,
#  'british': 9,
#  'medicine': 9,
#  'cough': 9,
#  'saltiness': 9,
#  'comparison': 9,
#  'fullness': 9,
#  'cocktail': 9,
#  'brine': 9,
#  'smoother': 9,
#  'chestnut': 9,
#  'mandarin': 9,
#  'blue': 9,
#  'twangy': 9,
#  'boring': 9,
#  'akin': 9,
#  'supple': 9,
#  'bat': 9,
#  'explosive': 9,
#  'refined': 9,
#  'adjust': 9,
#  'gose': 9,
#  'quaffable': 9,
#  'oakiness': 9,
#  'powdery': 9,
#  'mouthful': 9,
#  'place': 9,
#  'ideal': 9,
#  'botanical': 9,
#  'leaf': 9,
#  'balsamic': 9,
#  'interested': 9,
#  'degree': 9,
#  'viscosity': 9,
#  'excited': 9,
#  'sherry': 9,
#  'midwest': 9,
#  'baby': 9,
#  'notch': 9,
#  'multiple': 9,
#  'bill': 9,
#  'draft': 9,
#  'fruitcake': 9,
#  'shift': 9,
#  'chile': 9,
#  'frothy': 9,
#  'simcoe': 9,
#  'chai': 9,
#  'ending': 9,
#  'step': 9,
#  'proper': 9,
#  'rock': 9,
#  'headflavor': 9,
#  'pint': 9,
#  'tip': 9,
#  'thickness': 9,
#  'delight': 9,
#  'trend': 9,
#  'underneath': 9,
#  'common': 9,
#  'witbier': 9,
#  'flow': 9,
#  ...}

# %%
palate_dict
# Out:
# {'medium': 15092,
#  'light': 7324,
#  'smooth': 3841,
#  'creamy': 3111,
#  'dry': 1878,
#  'bodied': 1835,
#  'soft': 1782,
#  'thin': 1766,
#  'thick': 1623,
#  'mouth': 1589,
#  'moderate': 1559,
#  'crisp': 1365,
#  'sweet': 1169,
#  'low': 952,
#  'brown': 919,
#  'bitterness': 915,
#  'bitter': 902,
#  'heavy': 887,
#  'dark': 840,
#  'average': 811,
#  'overall': 791,
#  'sticky': 767,
#  'golden': 767,
#  'black': 750,
#  'white': 749,
#  'clean': 705,
#  'rich': 703,
#  'slick': 675,
#  'hazy': 653,
#  'big': 652,
#  'clear': 646,
#  'mid': 623,
#  'amber': 621,
#  'orange': 614,
#  'lively': 589,
#  'note': 578,
#  'solid': 559,
#  'decent': 522,
#  'high': 508,
#  'mild': 498,
#  'sweetness': 485,
#  'alcohol': 478,
#  'balanced': 477,
#  'fruit': 476,
#  'oily': 475,
#  'chocolate': 473,
#  'med': 441,
#  'citrus': 422,
#  'chewy': 421,
#  'small': 419,
#  'yellow': 405,
#  'deep': 401,
#  'nose': 398,
#  'easy': 382,
#  'copper': 378,
#  'watery': 378,
#  'silky': 358,
#  'refreshing': 351,
#  'coffee': 347,
#  'tart': 328,
#  'slight': 326,
#  'lot': 325,
#  'carb': 308,
#  'velvety': 304,
#  'drinkable': 298,
#  'excellent': 284,
#  'cloudy': 283,
#  'gold': 274,
#  'strong': 273,
#  'caramel': 272,
#  'syrupy': 272,
#  'spice': 272,
#  'fruity': 260,
#  'aftertaste': 256,
#  'yeast': 256,
#  'touch': 253,
#  'perfect': 249,
#  'pine': 242,
#  'juicy': 236,
#  'semi': 234,
#  'bright': 233,
#  'wheat': 228,
#  'balance': 227,
#  'sip': 227,
#  'opaque': 222,
#  'colored': 216,
#  'fizzy': 215,
#  'finger': 213,
#  'spicy': 211,
#  'style': 208,
#  'pleasant': 205,
#  'pale': 204,
#  'long': 203,
#  'firm': 199,
#  'vanilla': 197,
#  'character': 195,
#  'sour': 194,
#  'grapefruit': 194,
#  'roasted': 193,
#  'red': 193,
#  'fine': 191,
#  'flat': 189,
#  'full': 186,
#  'end': 186,
#  'drinkability': 184,
#  'tasty': 183,
#  'earthy': 180,
#  'hint': 176,
#  'level': 175,
#  'brew': 175,
#  'sharp': 174,
#  'stout': 172,
#  'bready': 171,
#  'interesting': 167,
#  'straw': 165,
#  'ale': 165,
#  'round': 165,
#  'lemon': 164,
#  'roast': 162,
#  'enjoyable': 159,
#  'floral': 159,
#  'ipa': 149,
#  'tongue': 148,
#  'roasty': 143,
#  'foamy': 140,
#  'resinous': 139,
#  'bread': 138,
#  'middle': 135,
#  'honey': 135,
#  'super': 134,
#  'viscous': 133,
#  'chalky': 133,
#  'resin': 131,
#  'effervescent': 130,
#  'oak': 130,
#  'fluffy': 129,
#  'grain': 128,
#  'funk': 127,
#  'bad': 126,
#  'sugar': 125,
#  'mahogany': 124,
#  'fresh': 124,
#  'dense': 122,
#  'complex': 120,
#  'tan': 120,
#  'grainy': 119,
#  'minimal': 118,
#  'acidity': 117,
#  'gentle': 116,
#  'fair': 116,
#  'cocoa': 115,
#  'plenty': 115,
#  'prickly': 115,
#  'presence': 115,
#  'awesome': 114,
#  'reddish': 111,
#  'tad': 110,
#  'tartness': 110,
#  'subtle': 108,
#  'cherry': 108,
#  'drinking': 107,
#  'bourbon': 106,
#  'bubbly': 106,
#  'murky': 106,
#  'way': 104,
#  'sessionability': 103,
#  'acidic': 103,
#  'tropical': 102,
#  'stuff': 102,
#  'huge': 100,
#  'ruby': 94,
#  'pepper': 93,
#  'smoke': 93,
#  'creaminess': 93,
#  'profile': 92,
#  'large': 92,
#  'bite': 91,
#  'right': 91,
#  'beige': 91,
#  'warmth': 90,
#  'wonderful': 88,
#  'carbonationoverall': 87,
#  'glass': 86,
#  'cream': 85,
#  'porter': 84,
#  'delicious': 83,
#  'substantial': 82,
#  'frothy': 82,
#  'wood': 81,
#  'active': 80,
#  'tangy': 79,
#  'citrusy': 79,
#  'boozy': 79,
#  'heat': 78,
#  'herbal': 78,
#  'spritzy': 76,
#  'mellow': 75,
#  'similar': 75,
#  'robust': 75,
#  'tight': 74,
#  'quality': 74,
#  'background': 74,
#  'sized': 74,
#  'warming': 73,
#  'blend': 73,
#  'bubble': 72,
#  'pineapple': 72,
#  'apple': 72,
#  'highlight': 72,
#  'earthiness': 72,
#  'toffee': 72,
#  'warm': 70,
#  'inch': 70,
#  'belgian': 70,
#  'milk': 69,
#  'fantastic': 69,
#  'sourness': 69,
#  'wine': 69,
#  'grassy': 68,
#  'funky': 68,
#  'lager': 67,
#  'cask': 67,
#  'modest': 67,
#  'delicate': 67,
#  'barrel': 67,
#  'yeasty': 66,
#  'fruitiness': 66,
#  'ample': 66,
#  'time': 66,
#  'ester': 66,
#  'sessionable': 65,
#  'grass': 65,
#  'typical': 65,
#  'thing': 65,
#  'juice': 64,
#  'linger': 64,
#  'lace': 63,
#  'coating': 63,
#  'amazing': 63,
#  'buttery': 62,
#  'rye': 62,
#  'stickiness': 62,
#  'present': 62,
#  'booze': 62,
#  'hue': 60,
#  'weak': 60,
#  'transparent': 60,
#  'beautiful': 60,
#  'clarity': 59,
#  'ton': 59,
#  'toast': 59,
#  'length': 59,
#  'tone': 58,
#  'peach': 58,
#  'noticeable': 58,
#  'faint': 57,
#  'unique': 57,
#  'wet': 57,
#  'appropriate': 56,
#  'abv': 56,
#  'dryness': 56,
#  'short': 56,
#  'complexity': 55,
#  'backbone': 55,
#  'banana': 54,
#  'spot': 53,
#  'bold': 53,
#  'lovely': 52,
#  'weight': 52,
#  'thickness': 52,
#  'raisin': 52,
#  'edge': 51,
#  'hoppiness': 51,
#  'bottle': 51,
#  'retention': 50,
#  'pretty': 50,
#  'lush': 50,
#  'zesty': 50,
#  'clove': 49,
#  'biscuit': 49,
#  'haze': 49,
#  'sure': 48,
#  'astringent': 48,
#  'flavorful': 48,
#  'earth': 48,
#  'peppery': 47,
#  'dank': 47,
#  'impressive': 47,
#  'woody': 47,
#  'coloured': 47,
#  'session': 47,
#  'molasse': 46,
#  'tannic': 46,
#  'hefty': 46,
#  'close': 46,
#  'milky': 45,
#  'berry': 45,
#  'smoky': 45,
#  'crystal': 45,
#  'effervescence': 44,
#  'soapy': 44,
#  'swallow': 43,
#  'raspberry': 43,
#  'syrup': 43,
#  'crispness': 43,
#  'pitch': 43,
#  'peel': 42,
#  'piney': 42,
#  'vinous': 42,
#  'saison': 42,
#  'herb': 42,
#  'chestnut': 42,
#  'rounded': 41,
#  'pink': 41,
#  'base': 41,
#  'smoothness': 41,
#  'real': 41,
#  'pleasing': 41,
#  'hot': 41,
#  'grape': 41,
#  'drink': 40,
#  'airy': 40,
#  'mineral': 40,
#  'simple': 39,
#  'harsh': 39,
#  'different': 39,
#  'residual': 39,
#  'cool': 38,
#  'aggressive': 38,
#  'heft': 38,
#  'kind': 38,
#  'bittersweet': 38,
#  'late': 38,
#  'nutty': 38,
#  'candy': 38,
#  'abundant': 37,
#  'initial': 37,
#  'slippery': 37,
#  'water': 37,
#  'spiciness': 37,
#  'depth': 36,
#  'undertone': 36,
#  'sugary': 36,
#  'tiny': 36,
#  'quick': 36,
#  'kick': 36,
#  'satisfying': 36,
#  'outstanding': 35,
#  'near': 35,
#  'nut': 35,
#  'oil': 35,
#  'acid': 35,
#  'element': 34,
#  'tingle': 34,
#  'ginger': 34,
#  'massive': 34,
#  'lightish': 34,
#  'unfiltered': 33,
#  'coat': 33,
#  'mix': 33,
#  'classic': 33,
#  'impression': 33,
#  'brownish': 32,
#  'oatmeal': 32,
#  'burn': 32,
#  'lasting': 32,
#  'astringency': 32,
#  'melon': 32,
#  'toasty': 32,
#  'ring': 32,
#  'biscuity': 32,
#  'intense': 32,
#  'coconut': 32,
#  'aspect': 32,
#  'standard': 32,
#  'tangerine': 32,
#  'fullness': 32,
#  'flavour': 32,
#  'jet': 31,
#  'bronze': 31,
#  'lite': 31,
#  'cola': 30,
#  'sort': 30,
#  'liquid': 30,
#  'example': 30,
#  'blonde': 30,
#  'translucent': 30,
#  'point': 30,
#  'upper': 29,
#  'thank': 29,
#  'velvet': 29,
#  'half': 29,
#  'tall': 29,
#  'summer': 29,
#  'pumpkin': 29,
#  'thinnish': 29,
#  'wheaty': 28,
#  'characteristic': 28,
#  'oat': 28,
#  'roastiness': 28,
#  'glow': 28,
#  'zest': 28,
#  'stick': 27,
#  'champagne': 27,
#  'effect': 27,
#  'tea': 27,
#  'start': 27,
#  'incredible': 27,
#  'pillowy': 27,
#  'feeling': 27,
#  'favorite': 27,
#  'finishmouthfeel': 26,
#  'lactic': 26,
#  'hay': 26,
#  'english': 26,
#  'carbonationdrinkability': 26,
#  'whiskey': 26,
#  'lime': 26,
#  'rough': 26,
#  'surprising': 25,
#  'smokey': 25,
#  'dipa': 25,
#  'luscious': 25,
#  'maple': 25,
#  'coriander': 25,
#  'dusty': 25,
#  'rind': 25,
#  'wispy': 25,
#  'duration': 25,
#  'exceptional': 25,
#  'carbo': 24,
#  'richness': 24,
#  'imperial': 24,
#  'espresso': 24,
#  'hearty': 24,
#  'pil': 24,
#  'hidden': 24,
#  'sensation': 24,
#  'layer': 24,
#  'experience': 24,
#  'overwhelming': 24,
#  'true': 24,
#  'hazed': 24,
#  'green': 24,
#  'licorice': 24,
#  'doughy': 23,
#  'cinnamon': 23,
#  'visible': 23,
#  'type': 23,
#  'lack': 23,
#  'salty': 23,
#  'lean': 23,
#  'khaki': 23,
#  'tingly': 23,
#  'supple': 23,
#  'tannin': 23,
#  'mocha': 23,
#  'prominent': 23,
#  'load': 23,
#  'cap': 22,
#  'citric': 22,
#  'vinegar': 22,
#  'old': 22,
#  'bubblegum': 22,
#  'mango': 22,
#  'alcoholic': 22,
#  'ish': 22,
#  'lactose': 22,
#  'version': 22,
#  'odd': 21,
#  'booziness': 21,
#  'adequate': 21,
#  'ending': 21,
#  'tobacco': 21,
#  'salt': 21,
#  'brewery': 21,
#  'quenching': 21,
#  'cracker': 20,
#  'tint': 20,
#  'metallic': 20,
#  'skin': 20,
#  'strength': 20,
#  'steady': 20,
#  'hefe': 20,
#  'cleanser': 20,
#  'quaffable': 20,
#  'dominant': 20,
#  'butter': 20,
#  'bone': 20,
#  'cider': 20,
#  'bittering': 20,
#  'pint': 20,
#  'leather': 19,
#  'minor': 19,
#  'garnet': 19,
#  'backing': 19,
#  'hard': 19,
#  'cleansing': 19,
#  'pure': 19,
#  'superb': 19,
#  'gritty': 18,
#  'sturdy': 18,
#  'bean': 18,
#  'drinker': 18,
#  'winter': 18,
#  'kinda': 18,
#  'backend': 18,
#  'coppery': 18,
#  'fun': 18,
#  'pilsner': 18,
#  'dull': 18,
#  'apparent': 18,
#  'second': 18,
#  'nuttiness': 17,
#  'slickness': 17,
#  'american': 17,
#  'extra': 17,
#  'ultra': 17,
#  'throat': 17,
#  'purple': 17,
#  'term': 17,
#  'quarter': 17,
#  'special': 17,
#  'fatigue': 17,
#  'viscosity': 17,
#  'pear': 17,
#  'goodness': 17,
#  'flow': 17,
#  'assertive': 17,
#  'plum': 17,
#  'definite': 17,
#  'snappy': 17,
#  'double': 17,
#  'healthy': 16,
#  'intensity': 16,
#  'smoother': 16,
#  'fade': 16,
#  'tap': 16,
#  'oaky': 16,
#  'aged': 16,
#  'stone': 16,
#  'combination': 16,
#  'tasting': 16,
#  'decadent': 16,
#  'phenolic': 16,
#  'muddy': 16,
#  'soda': 16,
#  'sediment': 16,
#  'charred': 16,
#  'surprise': 16,
#  'resiny': 16,
#  'middling': 16,
#  'blueberry': 16,
#  'acetic': 16,
#  'accent': 16,
#  'score': 16,
#  'ripe': 16,
#  'smokiness': 16,
#  'cereal': 16,
#  'world': 15,
#  'proper': 15,
#  'wise': 15,
#  'dough': 15,
#  'worth': 15,
#  'wrecker': 15,
#  'strawberry': 15,
#  'job': 15,
#  'barleywine': 15,
#  'significant': 15,
#  'cloying': 15,
#  'drier': 15,
#  'wit': 15,
#  'weird': 15,
#  'sudsy': 15,
#  'barley': 15,
#  'film': 15,
#  'cold': 14,
#  'coarse': 14,
#  'berliner': 14,
#  'orangish': 14,
#  'tulip': 14,
#  'prevalent': 14,
#  'zippy': 14,
#  'bock': 14,
#  'yellowish': 14,
#  'reminiscent': 14,
#  'vibrant': 14,
#  'distinct': 14,
#  'mint': 14,
#  'gorgeous': 14,
#  'inky': 14,
#  'spiced': 14,
#  'subdued': 14,
#  'blackish': 14,
#  'ashy': 14,
#  'crimson': 14,
#  'fig': 14,
#  'normal': 14,
#  'puckering': 14,
#  'almond': 14,
#  'early': 14,
#  'line': 13,
#  'neutral': 13,
#  'nutmeg': 13,
#  'tinge': 13,
#  'crushable': 13,
#  'carbonationo': 13,
#  'dose': 13,
#  'powdery': 13,
#  'fluid': 13,
#  'fuzzy': 13,
#  'persistent': 13,
#  'pulpy': 13,
#  'lip': 13,
#  'ideal': 13,
#  'rocky': 13,
#  'luxurious': 13,
#  'puffy': 13,
#  'pie': 13,
#  'vegetal': 13,
#  'wild': 13,
#  'phenol': 13,
#  'okay': 12,
#  'brass': 12,
#  'odor': 12,
#  'slow': 12,
#  'fullish': 12,
#  'lacking': 12,
#  'flower': 12,
#  'breadiness': 12,
#  'course': 12,
#  'brewpub': 12,
#  'main': 12,
#  'cranberry': 12,
#  'general': 12,
#  'unusual': 12,
#  'barnyard': 12,
#  'citru': 12,
#  'day': 12,
#  'sting': 12,
#  'winner': 12,
#  'overtone': 12,
#  'mind': 12,
#  'fat': 12,
#  'hit': 12,
#  'spare': 12,
#  'lingering': 12,
#  'rum': 12,
#  'delightful': 12,
#  'entry': 12,
#  'biting': 12,
#  'rustic': 12,
#  'walnut': 12,
#  'punch': 12,
#  'haziness': 11,
#  'doppelbock': 11,
#  'respectable': 11,
#  'department': 11,
#  'quad': 11,
#  'generous': 11,
#  'skim': 11,
#  'dryish': 11,
#  'onion': 11,
#  'borderline': 11,
#  'fruittiness': 11,
#  'brilliant': 11,
#  'upfront': 11,
#  'sense': 11,
#  'traditional': 11,
#  'evident': 11,
#  'chewiness': 11,
#  'slim': 11,
#  'bomb': 11,
#  'crackery': 11,
#  'natural': 11,
#  'funkiness': 11,
#  'hazelnut': 11,
#  'thirst': 11,
#  'size': 11,
#  'treat': 11,
#  'toasted': 11,
#  'aging': 11,
#  'peat': 11,
#  'shade': 11,
#  'nitro': 11,
#  'lightness': 10,
#  'regular': 10,
#  'lemongrass': 10,
#  'consistent': 10,
#  'transition': 10,
#  'lemony': 10,
#  'irish': 10,
#  'sipping': 10,
#  'dessert': 10,
#  'surface': 10,
#  'disappointing': 10,
#  'medicinal': 10,
#  'fuller': 10,
#  'sharpness': 10,
#  'rating': 10,
#  'cake': 10,
#  'consistency': 10,
#  'carbonic': 10,
#  'powerful': 10,
#  'issue': 10,
#  'lambic': 10,
#  'rusty': 10,
#  'ease': 10,
#  'substance': 10,
#  'marmalade': 10,
#  'peanut': 10,
#  'brisk': 10,
#  'burgundy': 10,
#  'dirty': 10,
#  'content': 10,
#  'edgy': 10,
#  'opinion': 10,
#  'drying': 9,
#  'limited': 9,
#  'work': 9,
#  'restrained': 9,
#  'place': 9,
#  'prune': 9,
#  'diacetyl': 9,
#  'finishf': 9,
#  'pungent': 9,
#  'density': 9,
#  'signature': 9,
#  'ash': 9,
#  'roll': 9,
#  'usual': 9,
#  'gum': 9,
#  'exquisite': 9,
#  'border': 9,
#  'silk': 9,
#  'fold': 9,
#  'non': 9,
#  'minty': 9,
#  'pithy': 9,
#  'result': 9,
#  'pillow': 9,
#  'offering': 9,
#  'adjust': 9,
#  'brewer': 9,
#  'fact': 9,
#  'pleasure': 9,
#  'chalkiness': 9,
#  'cookie': 9,
#  'tripel': 9,
#  'certain': 9,
#  'carbination': 9,
#  'area': 9,
#  'musty': 9,
#  'oxidation': 9,
#  'sipper': 9,
#  'rear': 9,
#  'minute': 9,
#  'snifter': 9,
#  'suit': 9,
#  'attractive': 9,
#  'spotty': 9,
#  'approachable': 9,
#  'loose': 9,
#  'baker': 9,
#  'juiciness': 9,
#  'ground': 9,
#  'port': 9,
#  'german': 9,
#  'forward': 9,
#  'weakly': 9,
#  'addition': 8,
#  'night': 8,
#  'combo': 8,
#  'pit': 8,
#  'category': 8,
#  'trace': 8,
#  'leg': 8,
#  'support': 8,
#  'sparkling': 8,
#  'peppercorn': 8,
#  'strange': 8,
#  'rolling': 8,
#  'ebony': 8,
#  'fleeting': 8,
#  'impressed': 8,
#  'carboantion': 8,
#  'noble': 8,
#  'surprised': 8,
#  'cheese': 8,
#  'meat': 8,
#  'sweetish': 8,
#  'killer': 8,
#  'change': 8,
#  'lead': 8,
#  'reason': 8,
#  'butterscotch': 8,
#  'action': 8,
#  'fast': 8,
#  'class': 8,
#  'collar': 8,
#  'bud': 8,
#  'dust': 8,
#  'backbeat': 8,
#  'major': 8,
#  'smallish': 8,
#  'hand': 8,
#  'lowish': 8,
#  'pop': 8,
#  'lacy': 8,
#  'glad': 8,
#  'assault': 8,
#  'hopping': 8,
#  'blackberry': 8,
#  'bill': 8,
#  'zingy': 8,
#  'straight': 8,
#  'nature': 8,
#  'poor': 8,
#  'filling': 8,
#  'clingy': 8,
#  'tree': 7,
#  'basic': 7,
#  'minus': 7,
#  'happy': 7,
#  'layered': 7,
#  'bouquet': 7,
#  'side': 7,
#  'play': 7,
#  'age': 7,
#  'food': 7,
#  'crazy': 7,
#  'actual': 7,
#  'man': 7,
#  'cedar': 7,
#  'pucker': 7,
#  'smacking': 7,
#  'treacle': 7,
#  'mirror': 7,
#  'anise': 7,
#  'distinctive': 7,
#  'lacto': 7,
#  'twist': 7,
#  'duvel': 7,
#  'plentiful': 7,
#  'aromatic': 7,
#  'finishm': 7,
#  'amount': 7,
#  'entire': 7,
#  'neat': 7,
#  'description': 7,
#  'farmhouse': 7,
#  'boot': 7,
#  'spruce': 7,
#  'chili': 7,
#  'ice': 7,
#  'raw': 7,
#  'roughness': 7,
#  'uncarbonated': 7,
#  'flabby': 7,
#  'sufficient': 7,
#  'hefeweizen': 7,
#  'obvious': 7,
#  'forefront': 7,
#  'notch': 7,
#  'dextrinous': 7,
#  'bruin': 7,
#  'savory': 7,
#  'straightforward': 7,
#  'mustiness': 7,
#  'cheer': 7,
#  'crust': 7,
#  'rush': 7,
#  'attack': 7,
#  'brief': 7,
#  'auburn': 7,
#  'wash': 7,
#  'effort': 7,
#  'potential': 7,
#  'tooth': 7,
#  'influence': 7,
#  'root': 7,
#  'witbier': 7,
#  'flowery': 7,
#  'notable': 7,
#  'seed': 7,
#  'road': 7,
#  'leafy': 7,
#  'muted': 7,
#  'gose': 7,
#  'complimentary': 7,
#  'rose': 7,
#  'marshmallow': 7,
#  'blood': 7,
#  'conditioning': 7,
#  'couple': 7,
#  'greet': 6,
#  'dance': 6,
#  'wateriness': 6,
#  'remarkable': 6,
#  'damp': 6,
#  'phenomenal': 6,
#  'crispy': 6,
#  'spectacular': 6,
#  'pinkish': 6,
#  'lighten': 6,
#  'milkshake': 6,
#  'temperature': 6,
#  'plus': 6,
#  'orangey': 6,
#  'lazy': 6,
#  'calm': 6,
#  'terrific': 6,
#  'midnight': 6,
#  'lucky': 6,
#  'silkiness': 6,
#  'exotic': 6,
#  'powder': 6,
#  'holiday': 6,
#  'ethanol': 6,
#  'abundance': 6,
#  'tired': 6,
#  'dunkel': 6,
#  'brandy': 6,
#  'maroon': 6,
#  'original': 6,
#  'explosive': 6,
#  'wave': 6,
#  'creamsicle': 6,
#  'durable': 6,
#  'mark': 6,
#  'cling': 6,
#  'rest': 6,
#  'gin': 6,
#  'oats': 6,
#  'elegant': 6,
#  'guava': 6,
#  'lithe': 6,
#  'component': 6,
#  'spectrum': 6,
#  'flash': 6,
#  'unpleasant': 6,
#  'rice': 6,
#  'additional': 6,
#  'nitrogen': 6,
#  'word': 6,
#  'fortunate': 6,
#  'prickle': 6,
#  'tickle': 6,
#  'fudge': 6,
#  'range': 6,
#  'lemonade': 6,
#  'need': 6,
#  'refreshment': 6,
#  'detectable': 6,
#  'offwhite': 6,
#  'nuance': 6,
#  'creme': 6,
#  'tickling': 6,
#  'mod': 6,
#  'whitish': 6,
#  'twang': 6,
#  'coated': 6,
#  'bitternesspalate': 6,
#  'leave': 6,
#  'perfection': 6,
#  'welcoming': 6,
#  'hair': 6,
#  'single': 6,
#  'cascade': 6,
#  'life': 6,
#  'carbonationd': 6,
#  'delight': 6,
#  'year': 6,
#  'dubbel': 6,
#  'grassiness': 6,
#  'acclimate': 6,
#  'key': 6,
#  'favor': 6,
#  'ink': 6,
#  'rindy': 6,
#  'acrid': 6,
#  'alot': 6,
#  'palette': 6,
#  'check': 6,
#  'shy': 6,
#  'price': 6,
#  'alc': 6,
#  'month': 6,
#  'blast': 6,
#  'corn': 6,
#  'esque': 5,
#  'cast': 5,
#  'cottony': 5,
#  'room': 5,
#  'enamel': 5,
#  'welcome': 5,
#  'underlying': 5,
#  'tang': 5,
#  'mouthwatering': 5,
#  'excessive': 5,
#  ...}

# %%
aroma_dict
# Out:
# {'dry': 5803,
#  'sweet': 5766,
#  'bitter': 4394,
#  'light': 3995,
#  'white': 3770,
#  'citrus': 3030,
#  'medium': 2506,
#  'chocolate': 2453,
#  'fruit': 2187,
#  'fruity': 2080,
#  'note': 1963,
#  'coffee': 1929,
#  'roasted': 1657,
#  'strong': 1635,
#  'bitterness': 1610,
#  'floral': 1581,
#  'dark': 1530,
#  'clean': 1489,
#  'smooth': 1446,
#  'tart': 1365,
#  'caramel': 1253,
#  'mild': 1240,
#  'pine': 1215,
#  'glass': 1200,
#  'spicy': 1125,
#  'big': 1097,
#  'earthy': 1095,
#  'sour': 1069,
#  'yeast': 1064,
#  'moderate': 1043,
#  'long': 1041,
#  'grapefruit': 997,
#  'crisp': 955,
#  'hint': 936,
#  'lace': 906,
#  'tropical': 887,
#  'lot': 881,
#  'slight': 857,
#  'alcohol': 840,
#  'roasty': 825,
#  'spice': 818,
#  'vanilla': 817,
#  'fresh': 813,
#  'rich': 716,
#  'lemon': 710,
#  'overall': 690,
#  'brown': 680,
#  'wheat': 672,
#  'bourbon': 671,
#  'grain': 658,
#  'heavy': 648,
#  'cherry': 614,
#  'solid': 610,
#  'sweetness': 609,
#  'retention': 572,
#  'roast': 568,
#  'bready': 563,
#  'orange': 555,
#  'pleasant': 547,
#  'similar': 546,
#  'beige': 544,
#  'herbal': 543,
#  'decent': 535,
#  'citrusy': 518,
#  'grassy': 500,
#  'creamy': 491,
#  'bread': 480,
#  'funky': 458,
#  'cocoa': 443,
#  'balanced': 425,
#  'touch': 420,
#  'honey': 415,
#  'yeasty': 414,
#  'piney': 409,
#  'earthiness': 397,
#  'soft': 397,
#  'complex': 395,
#  'oak': 391,
#  'semi': 389,
#  'toffee': 387,
#  'interesting': 377,
#  'faint': 372,
#  'nutty': 371,
#  'banana': 371,
#  'bodied': 370,
#  'belgian': 366,
#  'sugar': 364,
#  'sticky': 354,
#  'grass': 353,
#  'black': 347,
#  'subtle': 346,
#  'tasty': 341,
#  'apple': 341,
#  'huge': 338,
#  'present': 337,
#  'pale': 328,
#  'pepper': 322,
#  'excellent': 321,
#  'juicy': 320,
#  'edge': 320,
#  'smoke': 318,
#  'pineapple': 312,
#  'thin': 311,
#  'funk': 306,
#  'clove': 301,
#  'tan': 291,
#  'bittersweet': 285,
#  'thick': 284,
#  'refreshing': 284,
#  'yellow': 283,
#  'grainy': 282,
#  'straw': 282,
#  'bright': 278,
#  'duration': 277,
#  'peppery': 274,
#  'resin': 270,
#  'easy': 263,
#  'golden': 261,
#  'wood': 259,
#  'aftertaste': 256,
#  'rye': 250,
#  'dank': 250,
#  'mix': 248,
#  'berry': 248,
#  'woody': 244,
#  'balance': 243,
#  'biscuit': 243,
#  'wine': 242,
#  'raspberry': 241,
#  'smoky': 240,
#  'boozy': 239,
#  'dryness': 237,
#  'tartness': 234,
#  'start': 225,
#  'drink': 216,
#  'bite': 212,
#  'grape': 212,
#  'molasse': 211,
#  'tangy': 209,
#  'small': 208,
#  'nose': 205,
#  'barrel': 205,
#  'mouth': 205,
#  'wonderful': 205,
#  'acidic': 205,
#  'character': 204,
#  'peach': 204,
#  'red': 199,
#  'brew': 198,
#  'clear': 198,
#  'milk': 197,
#  'bottle': 196,
#  'ale': 191,
#  'deep': 190,
#  'raisin': 186,
#  'hazy': 181,
#  'sharp': 179,
#  'smokey': 178,
#  'bubble': 176,
#  'stuff': 175,
#  'spiciness': 174,
#  'whiskey': 172,
#  'musty': 169,
#  'drinkable': 167,
#  'warm': 166,
#  'green': 165,
#  'resinous': 164,
#  'candy': 164,
#  'minimal': 162,
#  'ester': 161,
#  'toast': 159,
#  'short': 159,
#  'ipa': 156,
#  'cloudy': 156,
#  'intense': 154,
#  'amber': 154,
#  'heat': 152,
#  'awesome': 151,
#  'nut': 150,
#  'quick': 149,
#  'plenty': 149,
#  'bad': 148,
#  'pungent': 147,
#  'toasty': 147,
#  'pumpkin': 146,
#  'delicious': 144,
#  'average': 143,
#  'ton': 142,
#  'way': 141,
#  'fantastic': 140,
#  'amazing': 139,
#  'tap': 139,
#  'low': 139,
#  'blend': 138,
#  'juice': 137,
#  'style': 136,
#  'booze': 135,
#  'dusty': 134,
#  'ginger': 133,
#  'mango': 133,
#  'typical': 133,
#  'enjoyable': 131,
#  'warming': 130,
#  'super': 129,
#  'earth': 129,
#  'presence': 129,
#  'lovely': 128,
#  'unique': 128,
#  'mellow': 128,
#  'gold': 128,
#  'cereal': 127,
#  'ring': 127,
#  'astringent': 126,
#  'coriander': 126,
#  'tangerine': 125,
#  'middle': 124,
#  'high': 123,
#  'maple': 120,
#  'melon': 119,
#  'hay': 119,
#  'spotty': 119,
#  'stout': 118,
#  'beautiful': 118,
#  'lactic': 116,
#  'initial': 116,
#  'noticeable': 115,
#  'linger': 114,
#  'sourness': 113,
#  'background': 112,
#  'citric': 112,
#  'peel': 112,
#  'rind': 111,
#  'lager': 111,
#  'bold': 110,
#  'perfect': 109,
#  'profile': 108,
#  'vinous': 107,
#  'weak': 107,
#  'sugary': 107,
#  'round': 107,
#  'toasted': 107,
#  'blueberry': 106,
#  'biscuity': 104,
#  'spiced': 104,
#  'lime': 104,
#  'metallic': 102,
#  'tongue': 100,
#  'bubblegum': 99,
#  'time': 99,
#  'fruitiness': 98,
#  'lemony': 98,
#  'plum': 97,
#  'hot': 96,
#  'thing': 96,
#  'stone': 96,
#  'barley': 96,
#  'noble': 94,
#  'foamy': 93,
#  'cream': 93,
#  'acidity': 93,
#  'zesty': 93,
#  'different': 92,
#  'brewery': 92,
#  'espresso': 92,
#  'fine': 92,
#  'quality': 91,
#  'med': 90,
#  'saison': 90,
#  'coconut': 90,
#  'vinegar': 89,
#  'cracker': 89,
#  'drinking': 88,
#  'herb': 88,
#  'flowery': 88,
#  'tea': 86,
#  'lively': 86,
#  'end': 85,
#  'zest': 85,
#  'combination': 85,
#  'mineral': 85,
#  'length': 84,
#  'copper': 84,
#  'buttery': 84,
#  'strawberry': 84,
#  'doughy': 84,
#  'classic': 84,
#  'corn': 83,
#  'simple': 82,
#  'slick': 82,
#  'oily': 82,
#  'robust': 81,
#  'real': 79,
#  'mocha': 79,
#  'butter': 79,
#  'film': 79,
#  'chewy': 78,
#  'licorice': 78,
#  'warmth': 77,
#  'dough': 77,
#  'soapy': 77,
#  'barnyard': 77,
#  'wet': 75,
#  'ripe': 74,
#  'odd': 74,
#  'hoppiness': 73,
#  'syrup': 73,
#  'burn': 73,
#  'pretty': 72,
#  'astringency': 72,
#  'peat': 71,
#  'salty': 71,
#  'rum': 71,
#  'alcoholic': 70,
#  'resiny': 69,
#  'wheaty': 69,
#  'gentle': 69,
#  'pleasing': 68,
#  'reminiscent': 68,
#  'modest': 68,
#  'dominant': 68,
#  'type': 67,
#  'skin': 67,
#  'peanut': 67,
#  'apparent': 67,
#  'distinct': 67,
#  'chalky': 67,
#  'porter': 66,
#  'watery': 65,
#  'colored': 65,
#  'oaky': 64,
#  'layer': 64,
#  'bittering': 64,
#  'pear': 63,
#  'thank': 63,
#  'load': 62,
#  'pink': 62,
#  'flower': 62,
#  'evident': 62,
#  'tone': 61,
#  'spruce': 61,
#  'sip': 61,
#  'leather': 61,
#  'fig': 61,
#  'complexity': 60,
#  'wild': 60,
#  'delicate': 59,
#  'tobacco': 59,
#  'level': 59,
#  'pilsner': 59,
#  'kick': 59,
#  'pure': 58,
#  'outstanding': 58,
#  'cinnamon': 58,
#  'fair': 57,
#  'khaki': 57,
#  'powerful': 57,
#  'bean': 57,
#  'syrupy': 56,
#  'drinkability': 55,
#  'treacle': 55,
#  'lasting': 54,
#  'grapefruity': 54,
#  'pil': 53,
#  'undertone': 53,
#  'impressive': 53,
#  'hard': 52,
#  'drier': 51,
#  'prominent': 51,
#  'sure': 51,
#  'definite': 51,
#  'flat': 50,
#  'summer': 50,
#  'flavorful': 49,
#  'subdued': 49,
#  'pie': 49,
#  'powder': 49,
#  'session': 49,
#  'harsh': 49,
#  'old': 49,
#  'flavour': 49,
#  'blackberry': 49,
#  'apricot': 48,
#  'strength': 48,
#  'ground': 48,
#  'mixed': 48,
#  'hazelnut': 48,
#  'tad': 47,
#  'spot': 47,
#  'nuttiness': 47,
#  'brewpub': 46,
#  'minty': 46,
#  'true': 46,
#  'incredible': 46,
#  'assertive': 45,
#  'characteristic': 45,
#  'cool': 45,
#  'oatmeal': 45,
#  'strange': 44,
#  'tannic': 44,
#  'standard': 44,
#  'cookie': 44,
#  'butterscotch': 44,
#  'anise': 44,
#  'acid': 43,
#  'lemongrass': 43,
#  'cascade': 43,
#  'hue': 43,
#  'date': 43,
#  'prune': 43,
#  'german': 43,
#  'fluffy': 42,
#  'lactose': 42,
#  'cold': 42,
#  'potent': 42,
#  'roastiness': 42,
#  'backbone': 42,
#  'piny': 42,
#  'element': 41,
#  'fragrant': 41,
#  'large': 41,
#  'citru': 41,
#  'nutmeg': 41,
#  'bubbly': 40,
#  'collar': 40,
#  'muted': 40,
#  'medicinal': 40,
#  'ashy': 39,
#  'accent': 39,
#  'salt': 39,
#  'bone': 39,
#  'farmhouse': 39,
#  'dissipate': 39,
#  'mint': 38,
#  'port': 38,
#  'weird': 38,
#  'delightful': 38,
#  'cranberry': 38,
#  'addition': 38,
#  'mixture': 38,
#  'silky': 38,
#  'english': 37,
#  'overwhelming': 37,
#  'massive': 37,
#  'aggressive': 37,
#  'reddish': 37,
#  'slow': 37,
#  'line': 37,
#  'version': 37,
#  'citra': 37,
#  'day': 36,
#  'raw': 36,
#  'forward': 36,
#  'acetic': 36,
#  'tannin': 36,
#  'sort': 36,
#  'crackery': 36,
#  'backend': 35,
#  'kind': 35,
#  'base': 35,
#  'minute': 35,
#  'aromatic': 35,
#  'haze': 35,
#  'gum': 35,
#  'opaque': 34,
#  'leafy': 34,
#  'surface': 34,
#  'stringy': 34,
#  'milky': 34,
#  'brandy': 34,
#  'cider': 33,
#  'finger': 33,
#  'abundant': 33,
#  'spare': 33,
#  'passion': 33,
#  'growler': 33,
#  'meat': 33,
#  'ish': 33,
#  'snappy': 33,
#  'sweetish': 33,
#  'currant': 32,
#  'perfume': 32,
#  'pronounced': 32,
#  'punch': 32,
#  'favorite': 32,
#  'chili': 32,
#  'right': 31,
#  'tiny': 31,
#  'winter': 31,
#  'pint': 31,
#  'cap': 31,
#  'brownie': 31,
#  'stick': 31,
#  'rounded': 31,
#  'highlight': 31,
#  'fizzy': 30,
#  'pithy': 30,
#  'effervescent': 30,
#  'spicey': 30,
#  'char': 30,
#  'oat': 30,
#  'phenolic': 30,
#  'fade': 29,
#  'close': 29,
#  'hefe': 29,
#  'smokiness': 29,
#  'american': 29,
#  'depth': 29,
#  'crazy': 29,
#  'surprising': 29,
#  'enticing': 29,
#  'lingering': 29,
#  'residual': 29,
#  'upfront': 29,
#  'candi': 28,
#  'worth': 28,
#  'obvious': 28,
#  'goodness': 28,
#  'appealing': 28,
#  'attractive': 28,
#  'unusual': 28,
#  'component': 28,
#  'aspect': 28,
#  'skunky': 27,
#  'ample': 27,
#  'estery': 27,
#  'barleywine': 27,
#  'bretty': 27,
#  'velvety': 27,
#  'carb': 27,
#  'messy': 27,
#  'dose': 27,
#  'mirror': 27,
#  'crispness': 27,
#  'snifter': 27,
#  'oil': 27,
#  'breadiness': 27,
#  'cedar': 27,
#  'guava': 27,
#  'satisfying': 27,
#  'crust': 26,
#  'abv': 26,
#  'water': 26,
#  'trace': 26,
#  'traditional': 26,
#  'lengthy': 26,
#  'fudge': 26,
#  'sense': 26,
#  'abrupt': 26,
#  'weed': 26,
#  'bouquet': 26,
#  'cake': 26,
#  'dryish': 25,
#  'hit': 25,
#  'match': 25,
#  'sediment': 25,
#  'familiar': 25,
#  'dense': 25,
#  'straight': 25,
#  'charred': 25,
#  'eggshell': 25,
#  'blast': 25,
#  'active': 25,
#  'inch': 25,
#  'phenol': 24,
#  'blood': 24,
#  'general': 24,
#  'overripe': 24,
#  'marshmallow': 24,
#  'watermelon': 24,
#  'scotch': 24,
#  'lacto': 24,
#  'superb': 24,
#  'booziness': 23,
#  'peachy': 23,
#  'passionfruit': 23,
#  'patchy': 23,
#  'leave': 23,
#  'biting': 23,
#  'inviting': 23,
#  'impression': 23,
#  'firm': 23,
#  'new': 23,
#  'mid': 23,
#  'imperial': 22,
#  'dominate': 22,
#  'whiff': 22,
#  'example': 22,
#  'chestnut': 22,
#  'tight': 22,
#  'liquid': 22,
#  'surprise': 22,
#  'point': 22,
#  'grassiness': 22,
#  'wit': 22,
#  'baked': 22,
#  'late': 22,
#  'juniper': 22,
#  'rough': 22,
#  'woodsy': 22,
#  'vegetal': 22,
#  'viscous': 21,
#  'hibiscus': 21,
#  'ruby': 21,
#  'dirty': 21,
#  'world': 21,
#  'crystal': 21,
#  'tulip': 21,
#  'nectarine': 21,
#  'musk': 21,
#  'savory': 20,
#  'kinda': 20,
#  'fun': 20,
#  'almond': 20,
#  'needle': 20,
#  'exceptional': 20,
#  'cheese': 20,
#  'peppercorn': 20,
#  'burst': 20,
#  'dipa': 20,
#  'purple': 20,
#  'funkiness': 20,
#  'sessionable': 20,
#  'aged': 20,
#  'overtone': 20,
#  'papaya': 19,
#  'dull': 19,
#  'hoppi': 19,
#  'notable': 19,
#  'power': 19,
#  'substantial': 19,
#  'husky': 19,
#  'onion': 19,
#  'vegetable': 19,
#  'leathery': 19,
#  'hearty': 19,
#  'dankness': 19,
#  'lavender': 19,
#  'consistent': 18,
#  'whisky': 18,
#  'vibrant': 18,
#  'bacon': 18,
#  'terrific': 18,
#  'champagne': 18,
#  'job': 18,
#  'baker': 18,
#  'wispy': 18,
#  'blanket': 18,
#  'tripel': 18,
#  'intriguing': 18,
#  'offering': 18,
#  'distinctive': 18,
#  'plastic': 18,
#  'carmel': 18,
#  'second': 18,
#  'effervescence': 18,
#  'pucker': 18,
#  'cut': 18,
#  'tint': 18,
#  'minor': 18,
#  'neutral': 18,
#  'cola': 17,
#  'special': 17,
#  'caramelized': 17,
#  'tinge': 17,
#  'kiwi': 17,
#  'liquor': 17,
#  'prevalent': 17,
#  'tree': 17,
#  'campfire': 17,
#  'cognac': 17,
#  'rice': 17,
#  'bead': 17,
#  'course': 17,
#  'balsamic': 17,
#  'prickly': 17,
#  'hopping': 17,
#  'charcoal': 17,
#  'mosaic': 17,
#  'detectable': 17,
#  'pecan': 16,
#  'musky': 16,
#  'peppermint': 16,
#  'bock': 16,
#  'waft': 16,
#  'brief': 16,
#  'saaz': 16,
#  'pith': 16,
#  'usual': 16,
#  'root': 16,
#  'non': 16,
#  'chocolatey': 16,
#  'kiss': 16,
#  'perfumy': 16,
#  'drinker': 16,
#  'significant': 16,
#  'amount': 16,
#  'stale': 16,
#  'cucumber': 16,
#  'graininess': 16,
#  'soap': 16,
#  'night': 16,
#  'authentic': 16,
#  'brett': 16,
#  'cone': 16,
#  'chocolaty': 16,
#  'pinkish': 16,
#  'alot': 16,
#  'limited': 15,
#  'creaminess': 15,
#  'swallow': 15,
#  'murky': 15,
#  'soy': 15,
#  'gorgeous': 15,
#  'froth': 15,
#  'mash': 15,
#  'generous': 15,
#  'woodiness': 15,
#  'fact': 15,
#  'tingle': 15,
#  'sized': 15,
#  'ultra': 15,
#  'foot': 15,
#  'allspice': 15,
#  'dessert': 15,
#  'frothy': 15,
#  'ash': 15,
#  'mustiness': 15,
#  'rating': 15,
#  'cask': 15,
#  'bland': 15,
#  'soda': 15,
#  'multi': 14,
#  'rose': 14,
#  'sweat': 14,
#  'british': 14,
#  'double': 14,
#  'irish': 14,
#  'esque': 14,
#  'deal': 14,
#  'trail': 14,
#  'mahogany': 14,
#  'intensity': 14,
#  'hefeweizen': 14,
#  'backing': 14,
#  'damp': 14,
#  'coating': 14,
#  'surprised': 14,
#  'sturdy': 14,
#  'dryer': 14,
#  'tasting': 14,
#  'appropriate': 14,
#  'lack': 14,
#  'place': 14,
#  'full': 14,
#  'quenching': 14,
#  'sauce': 14,
#  'marmalade': 14,
#  'looking': 14,
#  'carbonationappearance': 14,
#  'brisk': 14,
#  'simcoe': 14,
#  'whitish': 14,
#  'side': 14,
#  'pit': 14,
#  'spectacular': 14,
#  'man': 14,
#  'dust': 14,
#  'bar': 14,
#  'sherry': 13,
#  'yummy': 13,
#  'lean': 13,
#  'pomegranate': 13,
#  'forest': 13,
#  'wave': 13,
#  'perfumey': 13,
#  'bourbony': 13,
#  'stickiness': 13,
#  'juiciness': 13,
#  'house': 13,
#  'class': 13,
#  'lip': 13,
#  'basil': 13,
#  'natural': 13,
#  'love': 13,
#  'cheesy': 13,
#  'airy': 13,
#  'clovey': 13,
#  'suggestion': 13,
#  'experience': 13,
#  'yeastiness': 13,
#  'milder': 13,
#  'pop': 13,
#  'horse': 13,
#  'generic': 13,
#  'gin': 13,
#  'puckering': 13,
#  'basement': 13,
#  'pumpernickel': 13,
#  'tang': 13,
#  'sage': 13,
#  'essence': 12,
#  'poor': 12,
#  'sourish': 12,
#  'lush': 12,
#  'sea': 12,
#  'straightforward': 12,
#  'acrid': 12,
#  'chamomile': 12,
#  'swirl': 12,
#  'crown': 12,
#  'chile': 12,
#  'heady': 12,
#  'walnut': 12,
#  'vague': 12,
#  'throat': 12,
#  'underwhelming': 12,
#  'jam': 12,
#  'cardamom': 12,
#  'patch': 12,
#  'clingy': 12,
#  'room': 12,
#  'regular': 12,
#  'work': 12,
#  'sipper': 12,
#  'predominant': 12,
#  'blonde': 12,
#  'year': 12,
#  'hidden': 12,
#  'smoothness': 12,
#  'honeysuckle': 12,
#  'bomber': 12,
#  'seed': 12,
#  'rosemary': 12,
#  'description': 12,
#  'nib': 12,
#  'skunk': 12,
#  'ecru': 12,
#  'able': 12,
#  'underlying': 12,
#  'metal': 12,
#  'term': 12,
#  'creme': 12,
#  'field': 11,
#  'danky': 11,
#  'watering': 11,
#  'cardboard': 11,
#  'chardonnay': 11,
#  'streaky': 11,
#  'killer': 11,
#  'impressed': 11,
#  'ivory': 11,
#  'pleasent': 11,
#  'proper': 11,
#  'unexpected': 11,
#  'rocky': 11,
#  'bomb': 11,
#  'pace': 11,
#  'boozey': 11,
#  'identical': 11,
#  'center': 11,
#  'cover': 11,
#  'tough': 11,
#  'drank': 11,
#  'additional': 11,
#  'diacetyl': 11,
#  'welcome': 11,
#  'department': 11,
#  'crushable': 11,
#  'unfiltered': 11,
#  'holiday': 11,
#  'oxidation': 11,
#  'orangey': 11,
#  'cotton': 11,
#  'cat': 11,
#  'tannish': 11,
#  'signature': 11,
#  'visible': 11,
#  'entire': 11,
#  'gritty': 11,
#  'sweaty': 11,
#  'normal': 11,
#  'husk': 11,
#  'score': 11,
#  'restrained': 11,
#  'drying': 11,
#  'berliner': 11,
#  'immediate': 11,
#  'face': 11,
#  'flava': 11,
#  'artificial': 11,
#  'brilliant': 10,
#  'brettanomyce': 10,
#  'disappointing': 10,
#  'cloying': 10,
#  'smack': 10,
#  'mind': 10,
#  'toastiness': 10,
#  'extreme': 10,
#  'effort': 10,
#  'twist': 10,
#  'weizen': 10,
#  'notch': 10,
#  'sheet': 10,
#  'thirst': 10,
#  'mandarin': 10,
#  'smelling': 10,
#  'rindy': 10,
#  'major': 10,
#  'noticable': 10,
#  'unpleasant': 10,
#  'couple': 10,
#  'nuts': 10,
#  'saltiness': 10,
#  'unsweetened': 10,
#  'calm': 10,
#  'witbier': 10,
#  'par': 10,
#  'half': 10,
#  'sulfur': 10,
#  'opinion': 10,
#  'quaffable': 10,
#  'chipotle': 10,
#  'pilsener': 10,
#  'stonefruit': 10,
#  'combo': 10,
#  'biter': 10,
#  'air': 10,
#  'pot': 10,
#  'sourdough': 10,
#  'tall': 10,
#  'akin': 10,
#  'coppery': 10,
#  'moment': 9,
#  'splash': 9,
#  'scant': 9,
#  'flemmy': 9,
#  'herbaceous': 9,
#  'harshness': 9,
#  'explosion': 9,
#  'layered': 9,
#  'pic': 9,
#  'pillowy': 9,
#  'basic': 9,
#  'emphasis': 9,
#  'action': 9,
#  'piss': 9,
#  'courtesy': 9,
#  'chunky': 9,
#  'batch': 9,
#  'neat': 9,
#  'appetizing': 9,
#  'scented': 9,
#  'translucent': 9,
#  'temperature': 9,
#  'influence': 9,
#  'equal': 9,
#  'return': 9,
#  'wee': 9,
#  'contrast': 9,
#  'spritzy': 9,
#  'churchkey': 9,
#  'sock': 9,
#  'french': 9,
#  'wooden': 9,
#  'chalk': 9,
#  'transition': 9,
#  'lacework': 9,
#  'phenomenal': 9,
#  'final': 9,
#  'form': 9,
#  'rubber': 9,
#  'sensation': 9,
#  'feature': 9,
#  'particular': 9,
#  'plain': 9,
#  'smacking': 9,
#  'brewer': 9,
#  'nondescript': 9,
#  'unripe': 9,
#  'leaf': 9,
#  'improvement': 9,
#  'bunch': 9,
#  'belgium': 9,
#  'nitro': 9,
#  'healthy': 9,
#  'decadent': 9,
#  'fascinating': 9,
#  'quaff': 9,
#  'food': 9,
#  'tame': 9,
#  'suit': 9,
#  'draft': 9,
#  'stinky': 9,
#  'piquant': 9,
#  'cup': 9,
#  'leg': 9,
#  'display': 9,
#  'mouthful': 9,
#  'rustic': 9,
#  'mimic': 8,
#  ...}

# %%
# count the number of keywords that appear in more than one category
count = 0
for key in aroma_dict.keys():
    if key in taste_dict.keys():
        count += 1
    if key in palate_dict.keys():
        count += 1
    if key in appearance_dict.keys():
        count += 1
    if key in carbonation_dict.keys():
        count += 1
        
print("Number of keywords that appear in more than one category:", count)
# Out:
# Number of keywords that appear in more than one category: 10053

# %% [markdown]
# We observe that we have many keywords that appear in every category, even though some categories do not have the same meaning (such as appearance and taste).

# %%
# drop rows where aroma, taste, palate, appearance and carbonation are missing
good_ratings_combined_df.dropna(subset=['aroma', 'taste', 'palate', 'appearance'], inplace=True)

# %%
def matching_keywords(text, list_keywords):
    # Process the text with spaCy
    doc = nlp(text.lower())

    result = []
    for token in doc:
        token = token.lemma_
        if token in list_keywords:
            result.append(token)
    
    return result

# %%
def find_top_keywords_by_month(df, keywords_dict, month, category, num_keywords):
    # Filter the DataFrame for the specified month
    month_df = df[df['month'] == month]

    # Find the best beer for the month based on average rating and review count
    best_beer_df = month_df.groupby('beer_id').agg({category: ['mean', 'count']}).reset_index()
    best_beer_df.columns = ['beer_id', 'average_rating', 'review_count']
    beer_stats = best_beer_df.sort_values(by=['review_count', 'average_rating'], ascending=[False, False])

    # Get the beer ID of the best beer for the month
    best_beer_id = beer_stats.iloc[0]['beer_id']
    
    # print the best beer id for the month
    print(f"Best beer for the month of {month}:", best_beer_id)

    # Filter reviews to keep only the reviews of the best beer
    best_beer_reviews = month_df[month_df['beer_id'] == best_beer_id]

    # Extract keywords from reviews using a matching function (e.g., matching_keywords)
    keyword_list = []
    for text in best_beer_reviews['text'].values.tolist():
        keyword_list.extend(matching_keywords(text, keywords_dict.keys()))

    # Count the number of times each keyword appears in the reviews
    keyword_counter = Counter(keyword_list)

    # Sort the dictionary by value
    sorted_keywords = dict(sorted(keyword_counter.items(), key=lambda item: item[1], reverse=True))

    # Return the top N keywords as a list of tuples (key, value)
    top_keywords = [(key, sorted_keywords[key]) for key in list(sorted_keywords.keys())[:num_keywords]]

    return top_keywords

# %% [markdown]
# ## Aroma analysis

# %%
# for each month, find the top 10 keywords
top_keywords_by_month = {}
for month in range(1, 13):
    top_keywords_by_month[month] = find_top_keywords_by_month(good_ratings_combined_df, month, 'aroma', 10)
    print("Month", month)
    print(top_keywords_by_month[month])
    print()
# Out:
# Best beer for the month of 1: 17112.0
# Month 1
# [('honey', 1048), ('citrus', 692), ('sweet', 660), ('grapefruit', 637), ('bottle', 553), ('orange', 546), ('alcohol', 506), ('out', 464), ('pine', 457), ('white', 443)]
#
# Best beer for the month of 2: 17112.0
# Month 2
# [('honey', 934), ('citrus', 662), ('sweet', 650), ('grapefruit', 554), ('orange', 522), ('bottle', 453), ('alcohol', 446), ('pine', 429), ('white', 426), ('out', 391)]
#
# Best beer for the month of 3: 15881.0
# Month 3
# [('amber', 526), ('citrus', 346), ('sweet', 335), ('pine', 274), ('white', 254), ('bottle', 244), ('caramel', 243), ('orange', 234), ('grapefruit', 233), ('bitter', 217)]
#
# Best beer for the month of 4: 19960.0
# Month 4
# [('bourbon', 1497), ('coffee', 1407), ('chocolate', 1183), ('dark', 771), ('vanilla', 725), ('stout', 637), ('black', 585), ('bottle', 463), ('alcohol', 395), ('thick', 363)]
#
# Best beer for the month of 5: 19960.0
# Month 5
# [('bourbon', 690), ('coffee', 607), ('chocolate', 511), ('dark', 318), ('vanilla', 296), ('black', 274), ('stout', 240), ('alcohol', 203), ('bottle', 188), ('thick', 163)]
#
# Best beer for the month of 6: 1094.0
# Month 6
# [('wheat', 214), ('orange', 173), ('light', 171), ('citrus', 150), ('summer', 135), ('white', 131), ('sweet', 124), ('yeast', 109), ('bottle', 106), ('golden', 89)]
#
# Best beer for the month of 7: 82250.0
# Month 7
# [('pine', 287), ('citrus', 276), ('orange', 249), ('grapefruit', 247), ('bitter', 238), ('sweet', 216), ('ipa', 208), ('alcohol', 200), ('white', 196), ('stone', 195)]
#
# Best beer for the month of 8: 7971.0
# Month 8
# [('pine', 212), ('citrus', 204), ('grapefruit', 174), ('bottle', 167), ('ipa', 138), ('bitter', 129), ('orange', 126), ('white', 123), ('can', 120), ('drink', 119)]
#
# Best beer for the month of 9: 6260.0
# Month 9
# [('pumpkin', 1487), ('spice', 645), ('ale', 404), ('cinnamon', 396), ('nutmeg', 364), ('brown', 345), ('pie', 280), ('sweet', 249), ('sugar', 235), ('orange', 204)]
#
# Best beer for the month of 10: 11757.0
# Month 10
# [('coffee', 1182), ('chocolate', 812), ('dark', 483), ('stout', 457), ('black', 377), ('roasted', 271), ('thick', 241), ('brown', 201), ('bitter', 192), ('smooth', 189)]
#
# Best beer for the month of 11: 1904.0
# Month 11
# [('ipa', 642), ('citrus', 584), ('pine', 556), ('year', 462), ('amber', 438), ('bitter', 384), ('medium', 378), ('white', 377), ('sweet', 360), ('bitterness', 358)]
#
# Best beer for the month of 12: 1904.0
# Month 12
# [('ipa', 543), ('citrus', 454), ('pine', 420), ('amber', 341), ('bitter', 311), ('white', 308), ('medium', 293), ('sweet', 274), ('grapefruit', 263), ('bottle', 260)]

# %%
# Create a 3x4 grid of subplots
fig, axes = plt.subplots(4, 3, figsize=(15, 10))
fig.suptitle('Aroma Keywords per Month', fontsize=16)

# Flatten the 3x4 subplot grid into a 1D array for iteration
axes = axes.flatten()

# Iterate over each key and create a subplot
for i, (key, data) in enumerate(top_keywords_by_month.items()):
    keywords, values = zip(*data)

    # Create a bar plot on the current subplot
    axes[i].bar(keywords, values)
    axes[i].set_title(f'Top 10 keywords for Month {key}')
    axes[i].set_xlabel('Keywords')
    axes[i].set_ylabel('Count')
    axes[i].tick_params(axis='x', rotation=45)

# Adjust layout to prevent overlapping
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %% [markdown]
# ## Taste analysis

# %%
# for each month, find the top 10 keywords
top_keywords_by_month_taste = {}
for month in range(1, 13):
    top_keywords_by_month_taste[month] = find_top_keywords_by_month(good_ratings_combined_df, taste_dict, month, 'taste', 10)
    print("Month", month)
    print(top_keywords_by_month_taste[month])
    print()
# Out:
# Best beer for the month of 1: 17112.0
# Month 1
# [('with', 2168), ('honey', 1048), ('citrus', 692), ('sweet', 660), ('grapefruit', 637), ('bottle', 553), ('orange', 546), ('more', 535), ('alcohol', 506), ('pine', 457)]
#
# Best beer for the month of 2: 17112.0
# Month 2
# [('with', 2109), ('honey', 934), ('citrus', 662), ('sweet', 650), ('grapefruit', 554), ('orange', 522), ('more', 516), ('bottle', 453), ('alcohol', 446), ('pine', 429)]
#
# Best beer for the month of 3: 15881.0
# Month 3
# [('with', 1239), ('amber', 526), ('citrus', 346), ('sweet', 335), ('more', 297), ('pine', 274), ('white', 254), ('bottle', 244), ('caramel', 243), ('orange', 234)]
#
# Best beer for the month of 4: 19960.0
# Month 4
# [('with', 1718), ('bourbon', 1497), ('coffee', 1407), ('chocolate', 1183), ('dark', 771), ('vanilla', 725), ('stout', 637), ('black', 585), ('more', 554), ('bottle', 463)]
#
# Best beer for the month of 5: 19960.0
# Month 5
# [('with', 764), ('bourbon', 690), ('coffee', 607), ('chocolate', 511), ('dark', 318), ('vanilla', 296), ('black', 274), ('stout', 240), ('more', 216), ('alcohol', 203)]
#
# Best beer for the month of 6: 1094.0
# Month 6
# [('with', 519), ('wheat', 214), ('orange', 173), ('light', 171), ('citrus', 150), ('summer', 135), ('white', 131), ('sweet', 124), ('yeast', 109), ('bottle', 106)]
#
# Best beer for the month of 7: 82250.0
# Month 7
# [('with', 894), ('pine', 287), ('citrus', 276), ('orange', 249), ('grapefruit', 247), ('bitter', 238), ('sweet', 216), ('ipa', 208), ('alcohol', 200), ('white', 196)]
#
# Best beer for the month of 8: 7971.0
# Month 8
# [('with', 628), ('pine', 212), ('citrus', 204), ('grapefruit', 174), ('bottle', 167), ('more', 152), ('ipa', 138), ('bitter', 129), ('orange', 126), ('white', 123)]
#
# Best beer for the month of 9: 6260.0
# Month 9
# [('pumpkin', 1487), ('with', 984), ('spice', 645), ('ale', 404), ('cinnamon', 396), ('nutmeg', 364), ('brown', 345), ('pie', 280), ('sweet', 249), ('sugar', 235)]
#
# Best beer for the month of 10: 11757.0
# Month 10
# [('coffee', 1182), ('with', 891), ('chocolate', 812), ('dark', 483), ('stout', 457), ('black', 377), ('roasted', 271), ('thick', 241), ('more', 224), ('brown', 201)]
#
# Best beer for the month of 11: 1904.0
# Month 11
# [('with', 2164), ('ipa', 642), ('citrus', 584), ('pine', 556), ('year', 462), ('amber', 438), ('more', 400), ('bitter', 384), ('medium', 378), ('white', 377)]
#
# Best beer for the month of 12: 1904.0
# Month 12
# [('with', 1680), ('ipa', 543), ('citrus', 454), ('pine', 420), ('more', 347), ('amber', 341), ('bitter', 311), ('white', 308), ('medium', 293), ('sweet', 274)]

# %% [markdown]
# ## Palate analysis

# %%
# for each month, find the top 10 keywords
top_keywords_by_month_palate = {}
for month in range(1, 13):
    top_keywords_by_month_palate[month] = find_top_keywords_by_month(good_ratings_combined_df, palate_dict, month, 'palate', 10)
    print("Month", month)
    print(top_keywords_by_month_palate[month])
    print()
# Out:
# Month 1
# [('honey', 1048), ('citrus', 692), ('sweet', 660), ('grapefruit', 637), ('bottle', 553), ('orange', 546), ('alcohol', 506), ('out', 464), ('pine', 457), ('white', 443)]
#
# Month 2
# [('honey', 934), ('citrus', 662), ('sweet', 650), ('grapefruit', 554), ('orange', 522), ('bottle', 453), ('alcohol', 446), ('pine', 429), ('white', 426), ('out', 391)]
#
# Month 3
# [('amber', 526), ('citrus', 346), ('sweet', 335), ('pine', 274), ('white', 254), ('bottle', 244), ('caramel', 243), ('orange', 234), ('grapefruit', 233), ('bitter', 217)]
#
# Month 4
# [('bourbon', 1497), ('coffee', 1407), ('chocolate', 1183), ('dark', 771), ('vanilla', 725), ('stout', 637), ('black', 585), ('bottle', 463), ('alcohol', 395), ('thick', 363)]
#
# Month 5
# [('bourbon', 690), ('coffee', 607), ('chocolate', 511), ('dark', 318), ('vanilla', 296), ('black', 274), ('stout', 240), ('alcohol', 203), ('bottle', 188), ('thick', 163)]
#
# Month 6
# [('wheat', 214), ('orange', 173), ('light', 171), ('citrus', 150), ('summer', 135), ('white', 131), ('sweet', 124), ('yeast', 109), ('bottle', 106), ('golden', 89)]
#
# Month 7
# [('pine', 287), ('citrus', 276), ('orange', 249), ('grapefruit', 247), ('bitter', 238), ('sweet', 216), ('ipa', 208), ('alcohol', 200), ('white', 196), ('stone', 195)]
#
# Month 8
# [('pine', 212), ('citrus', 204), ('grapefruit', 174), ('bottle', 167), ('ipa', 138), ('bitter', 129), ('orange', 126), ('white', 123), ('can', 120), ('drink', 119)]
#
# Month 9
# [('pumpkin', 1487), ('spice', 645), ('ale', 404), ('cinnamon', 396), ('nutmeg', 364), ('brown', 345), ('pie', 280), ('sweet', 249), ('sugar', 235), ('orange', 204)]
#
# Month 10
# [('coffee', 1182), ('chocolate', 812), ('dark', 483), ('stout', 457), ('black', 377), ('roasted', 271), ('thick', 241), ('brown', 201), ('bitter', 192), ('smooth', 189)]
#
# Month 11
# [('ipa', 642), ('citrus', 584), ('pine', 556), ('year', 462), ('amber', 438), ('bitter', 384), ('medium', 378), ('white', 377), ('sweet', 360), ('bitterness', 358)]
#
# Month 12
# [('ipa', 543), ('citrus', 454), ('pine', 420), ('amber', 341), ('bitter', 311), ('white', 308), ('medium', 293), ('sweet', 274), ('grapefruit', 263), ('bottle', 260)]

# %% [markdown]
# ## Appearance analysis

# %%
# for each month, find the top 10 keywords
top_keywords_by_month_appearance = {}
for month in range(1, 13):
    top_keywords_by_month_appearance[month] = find_top_keywords_by_month(good_ratings_combined_df, appearance_dict, month, 'appearance', 10)
    print("Month", month)
    print(top_keywords_by_month_appearance[month])
    print()
# Out:
# Best beer for the month of 1: 17112.0
# Month 1
# [('and', 4104), ('honey', 1048), ('citrus', 692), ('sweet', 660), ('grapefruit', 637), ('bottle', 553), ('orange', 546), ('alcohol', 506), ('pine', 457), ('white', 443)]
#
# Best beer for the month of 2: 17112.0
# Month 2
# [('and', 3788), ('honey', 934), ('citrus', 662), ('sweet', 650), ('grapefruit', 554), ('orange', 522), ('bottle', 453), ('alcohol', 446), ('pine', 429), ('white', 426)]
#
# Best beer for the month of 3: 15881.0
# Month 3
# [('and', 2125), ('amber', 526), ('citrus', 346), ('sweet', 335), ('pine', 274), ('white', 254), ('bottle', 244), ('caramel', 243), ('orange', 234), ('grapefruit', 233)]
#
# Best beer for the month of 4: 19960.0
# Month 4
# [('and', 3682), ('bourbon', 1497), ('coffee', 1407), ('chocolate', 1183), ('dark', 771), ('vanilla', 725), ('stout', 637), ('black', 585), ('bottle', 463), ('alcohol', 395)]
#
# Best beer for the month of 5: 19960.0
# Month 5
# [('and', 1635), ('bourbon', 690), ('coffee', 607), ('chocolate', 511), ('dark', 318), ('vanilla', 296), ('black', 274), ('stout', 240), ('alcohol', 203), ('bottle', 188)]
#
# Best beer for the month of 6: 1094.0
# Month 6
# [('and', 833), ('wheat', 214), ('orange', 173), ('light', 171), ('citrus', 150), ('summer', 135), ('white', 131), ('sweet', 124), ('yeast', 109), ('bottle', 106)]
#
# Best beer for the month of 7: 82250.0
# Month 7
# [('and', 1599), ('pine', 287), ('citrus', 276), ('orange', 249), ('grapefruit', 247), ('bitter', 238), ('sweet', 216), ('ipa', 208), ('alcohol', 200), ('white', 196)]
#
# Best beer for the month of 8: 7971.0
# Month 8
# [('and', 1202), ('pine', 212), ('citrus', 204), ('grapefruit', 174), ('bottle', 167), ('ipa', 138), ('bitter', 129), ('orange', 126), ('white', 123), ('can', 120)]
#
# Best beer for the month of 9: 6260.0
# Month 9
# [('and', 1822), ('pumpkin', 1487), ('spice', 645), ('ale', 404), ('cinnamon', 396), ('nutmeg', 364), ('brown', 345), ('pie', 280), ('sweet', 249), ('sugar', 235)]
#
# Best beer for the month of 10: 11757.0
# Month 10
# [('and', 1776), ('coffee', 1182), ('chocolate', 812), ('dark', 483), ('stout', 457), ('black', 377), ('roasted', 271), ('thick', 241), ('brown', 201), ('bitter', 192)]
#
# Best beer for the month of 11: 1904.0
# Month 11
# [('and', 3589), ('ipa', 642), ('citrus', 584), ('pine', 556), ('year', 462), ('amber', 438), ('bitter', 384), ('medium', 378), ('white', 377), ('sweet', 360)]
#
# Best beer for the month of 12: 1904.0
# Month 12
# [('and', 2729), ('ipa', 543), ('citrus', 454), ('pine', 420), ('amber', 341), ('bitter', 311), ('white', 308), ('medium', 293), ('sweet', 274), ('grapefruit', 263)]
